# %%
import pandas as pd

from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology.EvaluationELM import EvaluationELM

# %%
hidden_size_record = pd.read_csv('hidden_size_record.csv')
hidden_result = EvaluationELM.evaluate_configurations_lcb(hidden_size_record)

# %%
Plotting.plot_elm_hidden_nodes(hidden_result, is_final_record=True,title_on=False)
# Out:
# [I/O Trace] Figure exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Figure\Report Figure\ELM_Hyperparameter_Trend_.png

# %%
optimization_record = pd.read_csv('optimization_record.csv')
optimize_result = EvaluationELM.evaluate_configurations_lcb(optimization_record)

# %%
Plotting.plot_RELM_hyperparam(optimize_result, is_final_record=True, title_on=False)
# Out:
# [I/O Trace] Figure exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Figure\Report Figure\RELM_Hyperparameter_Trend_.png
