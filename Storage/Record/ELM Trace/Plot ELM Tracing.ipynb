# %%
import pandas as pd
from Pipeline.Methodology.EvaluationELM import EvaluationELM

# %%
df = pd.read_csv('hidden_size_record.csv')

# %%
evaluator = EvaluationELM(None)

df1 = evaluator.random_seed_metrics(df)
df1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 evaluator = EvaluationELM(None)
#       3 df1 = evaluator.random_seed_metrics(df)
#       4 df1
#
# File ~\PycharmProjects\COMP3200_Individual_Project\Pipeline\Methodology\EvaluationELM.py:35, in EvaluationELM.__init__(self, activation_function, use_raw_data, data_scaling, elm_init_seed_range, k_fold)
#      33     self.gallstone_dataset.fetch_raw_data_path()
#      34 else:
# ---> 35     self.gallstone_dataset.fetch_cleaned_data_path()
#      37 self.gallstone_dataset.cv_test_split(self.k_fold)
#      39 self.feature_size = self.gallstone_dataset.x.shape[1]
#
# File ~\PycharmProjects\COMP3200_Individual_Project\Pipeline\Global\GallstoneDataSet.py:32, in GallstoneDataSet.fetch_cleaned_data_path(self)
#      30 self.file_path = '../../Storage/Dataset/Cleaned_Gallstone_Dataset_FE.csv'
# ...
