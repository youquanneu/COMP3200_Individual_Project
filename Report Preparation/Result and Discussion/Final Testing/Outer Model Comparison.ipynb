# %%
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
unused_column =['Hidden_Nodes','Lambda_Value','Solution_Size','Trial_Limit','Max_Iteration','Precision','Recall','NPV','Specificity','F2-Score','Bal Accuracy']

# %%
model_files = {
    "MLP"           : "cleaned_MLP_Results.csv",
    "Random Forest" : "cleaned_RF_Results.csv",
    "HGBC"          : "cleaned_HGBC_Results.csv",
    "Bagging LRC"   : "cleaned_Bagging_LRC_Results.csv",
    "LRC"           : "cleaned_LogReg_Classifier_Results.csv",
    "SVC"           : "cleaned_LinearSVC_Results.csv",
    "ABC RELM CV"   : "cleaned_ABC_RELM_CV_Algo_3_2_80SN_120MI_Results.csv"
}
model_order = [
    "MLP",
    "Random Forest",
    "HGBC",
    "Bagging LRC",
    "LRC",
    "SVC",
    "ABC RELM CV"]

# %%
(df_s_all1, p_vals_s1), (df_f_all1, df_f_pivot1, p_vals_f1) = ABC_Testing.get_result_stats(
    model_dict      = model_files,
    target_order    = model_order,
    main_model_name = "ABC RELM CV",
    metric_name     = 'MCC',
    show_macro      = True
)
df1_stable ,df1_general = ABC_Testing.get_test_result_summaries(model_files,p_vals_s1,p_vals_f1)
ABC_Testing.format_summaries_for_academic_report(df1_stable)
# Out:
#       model_name         Accuracy         F1-Score              MCC  \
# 0            MLP  0.6826 ± 0.0351  0.6719 ± 0.0469  0.3811 ± 0.0657
# 1  Random Forest  0.7446 ± 0.0115  0.7378 ± 0.0117  0.4899 ± 0.0231
# 2           HGBC  0.7382 ± 0.0164  0.7245 ± 0.0182  0.4790 ± 0.0332
# 3    Bagging LRC  0.7405 ± 0.0065  0.7249 ± 0.0079  0.4829 ± 0.0128
# 4            LRC  0.7776 ± 0.0000  0.7546 ± 0.0000  0.5610 ± 0.0000
# 5            SVC  0.7560 ± 0.0000  0.7366 ± 0.0000  0.5146 ± 0.0000
# 6    ABC RELM CV  0.7453 ± 0.0203  0.7169 ± 0.0225  0.4980 ± 0.0421
#
#    Wilcoxon_p_MCC Wilcoxon_dir_MCC
# 0    1.317169e-11               +1
# 1    1.909597e-01                0
# 2    2.028861e-02               +1
# 3    2.282836e-02               +1
# 4    3.272049e-12               -1
# 5    2.282836e-02               -1
# 6             NaN              N/A

# %%
ABC_Testing.format_summaries_for_academic_report(df1_general)
# Out:
#       model_name         Accuracy         F1-Score              MCC  \
# 0            MLP  0.7487 ± 0.0442  0.7394 ± 0.0420  0.5098 ± 0.0872
# 1  Random Forest  0.7804 ± 0.0326  0.7707 ± 0.0289  0.5625 ± 0.0661
# 2           HGBC  0.7756 ± 0.0286  0.7635 ± 0.0287  0.5537 ± 0.0569
# 3    Bagging LRC  0.7855 ± 0.0443  0.7732 ± 0.0473  0.5729 ± 0.0884
# 4            LRC  0.8269 ± 0.0493  0.8136 ± 0.0589  0.6572 ± 0.0962
# 5            SVC  0.8143 ± 0.0583  0.8018 ± 0.0652  0.6309 ± 0.1163
# 6    ABC RELM CV  0.7956 ± 0.0437  0.7741 ± 0.0491  0.5996 ± 0.0883
#
#    T_test_p_MCC T_test_dir_MCC
# 0      0.179447              0
# 1      0.617709              0
# 2      0.604296              0
# 3      0.617709              0
# 4      0.117670              0
# 5      0.604296              0
# 6           NaN            N/A

# %%
Plotting.plot_test_results(
    df_s_all1, p_vals_s1,
    df_f_all1, df_f_pivot1, p_vals_f1,
    target_order    = model_order,
    main_model_name = "ABC RELM CV",
    show_macro      = True,
    global_title    = "Baseline Models Comparison"
)
