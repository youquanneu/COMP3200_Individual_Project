# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCVEnsemble import ArtificialBeeColonyElmCVEnsemble
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Methodology.ABC_Testing import cross_seed_testing

# %%
model_configs = GlobalSetting.get_model_configs()
config = next(item for item in model_configs if item['Model_Types'] == 'Grid_Optimization')
model_name = "ABC_CVEnsemble_ELM"

# %%
result_of_model = cross_seed_testing(ArtificialBeeColonyElmCVEnsemble,
                                     model_name = model_name,
                                     model_types= config['Model_Types'],
                                     cv_folds   = 5,
                                     force_lambda= 0.0,
                                     is_abc_opt = True,
                                     data_scaling=False)
# Out:
# Seed 130  | Iteration 010 complete | Duration: 0.0565s | Scout Triggers: 3 | Best Fitness: 0.749065
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_CVEnsemble_ELM_Results.csv
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_CVEnsemble_ELM_Convergence.csv
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_CVEnsemble_ELM_Scout_History.csv

# %%
df_result , df_con , df_sco = result_of_model
df_result.describe()
# Out:
#        Hidden_Nodes  Lambda_Value     Fold_ID        Seed    Accuracy  \
# count         150.0         150.0  150.000000  150.000000  150.000000
# mean           34.0           0.0    2.000000  115.500000    0.747110
# std             0.0           0.0    1.418951    8.684438    0.058602
# min            34.0           0.0    0.000000  101.000000    0.562500
# 25%            34.0           0.0    1.000000  108.000000    0.703125
# 50%            34.0           0.0    2.000000  115.500000    0.750000
# 75%            34.0           0.0    3.000000  123.000000    0.781250
# max            34.0           0.0    4.000000  130.000000    0.875000
#
#         Precision      Recall         NPV  Specificity    F1-Score  \
# count  150.000000  150.000000  150.000000   150.000000  150.000000
# mean     0.786817    0.673938    0.723931     0.818807    0.722370
# std      0.062506    0.101325    0.068174     0.062409    0.071916
# min      0.571429    0.468750    0.555556     0.625000    0.533333
# 25%      0.739533    0.593750    0.668605     0.781250    0.666667
# 50%      0.791667    0.656250    0.714286     0.818182    0.721311
# 75%      0.833333    0.750000    0.771429     0.875000    0.779661
# max      0.916667    0.906250    0.892857     0.937500    0.875000
#
#          F2-Score  Bal Accuracy         MCC
# count  150.000000    150.000000  150.000000
# mean     0.691820      0.746372    0.501565
# std      0.089429      0.058634    0.115795
# min      0.503356      0.562500    0.125988
# 25%      0.616883      0.703125    0.411302
# 50%      0.680272      0.749389    0.500490
# 75%      0.756579      0.781250    0.576127
# max      0.884146      0.875000    0.750000
