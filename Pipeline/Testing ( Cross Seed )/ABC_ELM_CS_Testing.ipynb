# %%
from Pipeline.Algorithm.ArtificialBeeColonyElm import ArtificialBeeColonyElm
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Methodology.ABC_Testing import cross_seed_testing

# %%
model_configs = GlobalSetting.get_model_configs()
config = next(item for item in model_configs if item['Model_Types'] == 'Grid_Optimization')
model_name = "ABC_ELM"

# %%
result_of_model = cross_seed_testing(ArtificialBeeColonyElm,
                                     model_name = model_name,
                                     model_types= config['Model_Types'],
                                     cv_folds   = 5,
                                     force_lambda= 0.0,
                                     is_abc_opt = True,
                                     data_scaling=True)
# Out:
# Seed 130  | Iteration 010 complete | Duration: 0.0119s | Scout Triggers: 2 | Best Fitness: 0.839125
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_ELM_Results.csv
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_ELM_Convergence.csv
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_ELM_Scout_History.csv

# %%
df_result , df_con , df_sco = result_of_model
df_result.describe()
# Out:
#        Hidden_Nodes  Lambda_Value     Fold_ID        Seed    Accuracy  \
# count         150.0         150.0  150.000000  150.000000  150.000000
# mean           34.0           0.0    2.000000  115.500000    0.749385
# std             0.0           0.0    1.418951    8.684438    0.055322
# min            34.0           0.0    0.000000  101.000000    0.625000
# 25%            34.0           0.0    1.000000  108.000000    0.703125
# 50%            34.0           0.0    2.000000  115.500000    0.750000
# 75%            34.0           0.0    3.000000  123.000000    0.796069
# max            34.0           0.0    4.000000  130.000000    0.859375
#
#         Precision      Recall         NPV  Specificity    F1-Score  \
# count  150.000000  150.000000  150.000000   150.000000  150.000000
# mean     0.790332    0.676089    0.726298     0.821275    0.724697
# std      0.062469    0.101620    0.066649     0.062785    0.069518
# min      0.642857    0.500000    0.609756     0.687500    0.581818
# 25%      0.750000    0.593750    0.675169     0.781250    0.677966
# 50%      0.782609    0.656250    0.716117     0.812500    0.720031
# 75%      0.833333    0.774194    0.781250     0.848485    0.780853
# max      0.954545    0.937500    0.920000     0.968750    0.861538
#
#          F2-Score  Bal Accuracy         MCC
# count  150.000000    150.000000  150.000000
# mean     0.693951      0.748682    0.506796
# std      0.088518      0.055309    0.109566
# min      0.529801      0.625000    0.251976
# 25%      0.620915      0.703125    0.416333
# 50%      0.679619      0.750000    0.507340
# 75%      0.775847      0.793152    0.594608
# max      0.898204      0.859375    0.719101
