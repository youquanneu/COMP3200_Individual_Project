# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Methodology.ABC_Testing import cross_seed_testing

# %%
model_configs = GlobalSetting.get_model_configs()
config = next(item for item in model_configs if item['Model_Types'] == 'Grid_Optimization')
model_name = "ABC_CV_ELM"
hidden_size = config['Hidden_Nodes']

# %%
result_of_model = cross_seed_testing(ArtificialBeeColonyElmCV,
                                     model_name = model_name,
                                     model_types= config['Model_Types'],
                                     cv_folds   = 5,
                                     force_lambda= 0.0,
                                     is_abc_opt = True,
                                     data_scaling=False)
# Out:
# Seed 130  | Iteration 010 complete | Duration: 0.0691s | Scout Triggers: 3 | Best Fitness: 0.749065
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_CV_ELM_Results.csv
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_CV_ELM_Convergence.csv
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_CV_ELM_Scout_History.csv

# %%
df_result , df_con , df_sco = result_of_model
df_result.describe()
# Out:
#        Hidden_Nodes  Lambda_Value     Fold_ID        Seed    Accuracy  \
# count         150.0         150.0  150.000000  150.000000  150.000000
# mean           34.0           0.0    2.000000  115.500000    0.747740
# std             0.0           0.0    1.418951    8.684438    0.058938
# min            34.0           0.0    0.000000  101.000000    0.578125
# 25%            34.0           0.0    1.000000  108.000000    0.703125
# 50%            34.0           0.0    2.000000  115.500000    0.750000
# 75%            34.0           0.0    3.000000  123.000000    0.781250
# max            34.0           0.0    4.000000  130.000000    0.859375
#
#         Precision      Recall         NPV  Specificity    F1-Score  \
# count  150.000000  150.000000  150.000000   150.000000  150.000000
# mean     0.787980    0.674153    0.724027     0.819798    0.723108
# std      0.064111    0.099842    0.067418     0.063529    0.071830
# min      0.586207    0.468750    0.571429     0.625000    0.557377
# 25%      0.742166    0.593750    0.668605     0.781250    0.666667
# 50%      0.796552    0.656250    0.716117     0.818182    0.720031
# 75%      0.837366    0.750000    0.777778     0.875000    0.778776
# max      0.923077    0.906250    0.892857     0.937500    0.861538
#
#          F2-Score  Bal Accuracy         MCC
# count  150.000000    150.000000  150.000000
# mean     0.692249      0.746976    0.502800
# std      0.088416      0.058926    0.116725
# min      0.503356      0.578125    0.156941
# 25%      0.617891      0.703125    0.421347
# 50%      0.680272      0.750000    0.503953
# 75%      0.761589      0.781823    0.580948
# max      0.884146      0.859375    0.722705
