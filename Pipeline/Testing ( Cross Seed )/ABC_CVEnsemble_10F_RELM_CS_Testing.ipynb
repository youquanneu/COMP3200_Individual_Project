# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCVEnsemble import ArtificialBeeColonyElmCVEnsemble
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Methodology.ABC_Testing import cross_seed_testing

# %%
model_configs = GlobalSetting.get_model_configs()
config = next(item for item in model_configs if item['Model_Types'] == 'Grid_Optimization')
model_name = "ABC_CVEnsemble_RELM"

# %%
result_of_model = cross_seed_testing(ArtificialBeeColonyElmCVEnsemble,
                                     model_name = model_name,
                                     model_types= config['Model_Types'],
                                     cv_folds   = 5,
                                     abc_cv_fold= 10,
                                     is_abc_opt = True,
                                     data_scaling=False)
# Out:
# Seed 130  | Iteration 010 complete | Duration: 0.0675s | Scout Triggers: 4 | Best Fitness: 0.684680
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_CVEnsemble_RELM_Results.csv
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_CVEnsemble_RELM_Convergence.csv
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_CVEnsemble_RELM_Scout_History.csv

# %%
df_result , df_con , df_sco = result_of_model
df_result.describe()
# Out:
#        Hidden_Nodes  Lambda_Value     Fold_ID        Seed    Accuracy  \
# count         150.0       150.000  150.000000  150.000000  150.000000
# mean           34.0         0.125    2.000000  115.500000    0.754560
# std             0.0         0.000    1.418951    8.684438    0.058333
# min            34.0         0.125    0.000000  101.000000    0.609375
# 25%            34.0         0.125    1.000000  108.000000    0.718750
# 50%            34.0         0.125    2.000000  115.500000    0.750000
# 75%            34.0         0.125    3.000000  123.000000    0.796875
# max            34.0         0.125    4.000000  130.000000    0.873016
#
#         Precision      Recall         NPV  Specificity    F1-Score  \
# count  150.000000  150.000000  150.000000   150.000000  150.000000
# mean     0.798416    0.678737    0.729701     0.828763    0.729452
# std      0.066781    0.104064    0.067254     0.066571    0.073043
# min      0.652174    0.468750    0.585366     0.687500    0.545455
# 25%      0.744643    0.593750    0.675169     0.781250    0.669355
# 50%      0.800000    0.656250    0.712406     0.818182    0.714286
# 75%      0.849038    0.774194    0.783784     0.878788    0.786885
# max      0.954545    0.875000    0.870968     0.969697    0.866667
#
#          F2-Score  Bal Accuracy         MCC
# count  150.000000    150.000000  150.000000
# mean     0.697354      0.753750    0.517576
# std      0.091472      0.058566    0.115548
# min      0.496689      0.609375    0.227951
# 25%      0.620915      0.714809    0.438247
# 50%      0.690789      0.750000    0.512556
# 75%      0.781250      0.796875    0.596377
# max      0.865385      0.872480    0.751566
