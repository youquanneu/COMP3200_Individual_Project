# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Methodology.ABC_Testing import cross_seed_testing

# %%
model_configs = GlobalSetting.get_model_configs()
config = next(item for item in model_configs if item['Model_Types'] == 'Grid_Optimization')
model_name = "ABC_CV_RELM"

# %%
result_of_model = cross_seed_testing(ArtificialBeeColonyElmCV,
                                     model_name = model_name,
                                     model_types= config['Model_Types'],
                                     cv_folds   = 5,
                                     is_abc_opt = True,
                                     data_scaling=False)
# Out:
# Seed 130  | Iteration 010 complete | Duration: 0.0539s | Scout Triggers: 3 | Best Fitness: 0.738629
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_CV_RELM_Results.csv
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_CV_RELM_Convergence.csv
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_CV_RELM_Scout_History.csv

# %%
df_result , df_con , df_sco = result_of_model
df_result.describe()
# Out:
#        Hidden_Nodes  Lambda_Value     Fold_ID        Seed    Accuracy  \
# count         150.0       150.000  150.000000  150.000000  150.000000
# mean           34.0         0.125    2.000000  115.500000    0.749029
# std             0.0         0.000    1.418951    8.684438    0.058450
# min            34.0         0.125    0.000000  101.000000    0.625000
# 25%            34.0         0.125    1.000000  108.000000    0.703125
# 50%            34.0         0.125    2.000000  115.500000    0.750000
# 75%            34.0         0.125    3.000000  123.000000    0.796875
# max            34.0         0.125    4.000000  130.000000    0.873016
#
#         Precision      Recall         NPV  Specificity    F1-Score  \
# count  150.000000  150.000000  150.000000   150.000000  150.000000
# mean     0.791493    0.676116    0.725301     0.820448    0.724958
# std      0.073017    0.099230    0.064788     0.075377    0.070698
# min      0.633333    0.500000    0.600000     0.625000    0.571429
# 25%      0.740741    0.593750    0.675000     0.781250    0.677966
# 50%      0.781929    0.666835    0.716117     0.812500    0.721311
# 75%      0.849038    0.768145    0.780382     0.875000    0.785476
# max      0.960000    0.875000    0.875000     0.969697    0.870968
#
#          F2-Score  Bal Accuracy         MCC
# count  150.000000    150.000000  150.000000
# mean     0.694021      0.748282    0.506458
# std      0.087018      0.058426    0.116953
# min      0.526316      0.625000    0.254514
# 25%      0.616883      0.703125    0.411706
# 50%      0.691307      0.748900    0.500490
# 75%      0.771760      0.796214    0.594040
# max      0.870968      0.872984    0.751566
