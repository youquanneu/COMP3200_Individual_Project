# %%
from Pipeline.Algorithm.ArtificialBeeColonyElm import ArtificialBeeColonyElm
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Methodology.ABC_Testing import cross_seed_testing

# %%
model_configs = GlobalSetting.get_model_configs()
config = next(item for item in model_configs if item['Model_Types'] == 'Grid_Optimization')
model_name = "ABC_RELM"

# %%
result_of_model = cross_seed_testing(ArtificialBeeColonyElm,
                                     model_name = model_name,
                                     model_types= config['Model_Types'],
                                     cv_folds   = 5,
                                     is_abc_opt = True,
                                     data_scaling=True)
# Out:
# Seed 130  | Iteration 010 complete | Duration: 0.0077s | Scout Triggers: 4 | Best Fitness: 0.823324
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_RELM_Results.csv
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_RELM_Convergence.csv
# [I/O Trace] Record exported successfully: ../../Storage/Record\ABC_RELM_Scout_History.csv

# %%
df_result , df_con , df_sco = result_of_model
df_result.describe()
# Out:
#        Hidden_Nodes  Lambda_Value     Fold_ID        Seed    Accuracy  \
# count         150.0       150.000  150.000000  150.000000  150.000000
# mean           34.0         0.125    2.000000  115.500000    0.755703
# std             0.0         0.000    1.418951    8.684438    0.058599
# min            34.0         0.125    0.000000  101.000000    0.609375
# 25%            34.0         0.125    1.000000  108.000000    0.718750
# 50%            34.0         0.125    2.000000  115.500000    0.750000
# 75%            34.0         0.125    3.000000  123.000000    0.796875
# max            34.0         0.125    4.000000  130.000000    0.888889
#
#         Precision      Recall         NPV  Specificity    F1-Score  \
# count  150.000000  150.000000  150.000000   150.000000  150.000000
# mean     0.799256    0.681935    0.729878     0.827904    0.732360
# std      0.071390    0.093385    0.063209     0.071801    0.069059
# min      0.620690    0.468750    0.600000     0.656250    0.590164
# 25%      0.750000    0.593750    0.681818     0.781250    0.678571
# 50%      0.800000    0.656250    0.723611     0.843750    0.732051
# 75%      0.857143    0.774194    0.787879     0.875000    0.793514
# max      0.956522    0.843750    0.857143     0.968750    0.881356
#
#          F2-Score  Bal Accuracy         MCC
# count  150.000000    150.000000  150.000000
# mean     0.700583      0.754920    0.519284
# std      0.083027      0.058656    0.117148
# min      0.513699      0.609375    0.219718
# 25%      0.633333      0.714076    0.437678
# 50%      0.688532      0.750000    0.526361
# 75%      0.771812      0.796875    0.616166
# max      0.855263      0.888105    0.780948
