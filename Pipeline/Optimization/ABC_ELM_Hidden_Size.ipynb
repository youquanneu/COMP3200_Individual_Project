# %% [markdown]
# ## Best Hidden Size

# %%
from Pipeline.Algorithm.ArtificialBeeColonyElm import ArtificialBeeColonyElm
from Pipeline.Global.GallstoneDataSet import GallstoneDataSet
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Global.Plotting import Plotting
from Pipeline.Optimization.ABC_Testing import abc_testing

# %%
gallstone_dataset = GallstoneDataSet()
gallstone_dataset.fetch_data_path_1()

features_size = gallstone_dataset.x_train.shape[1]
x_train_scaled = gallstone_dataset.x_train_scaled
x_test_scaled  = gallstone_dataset.x_test_scaled
y_train = gallstone_dataset.y_train
y_test  = gallstone_dataset.y_test

# %%
best_hidden_config = GlobalSetting.get_config_by_type("Best_Hidden_Nodes")
best_hidden_size = best_hidden_config["Hidden_Nodes"] if best_hidden_config else None

# %%
abc_elm_hidden  = ArtificialBeeColonyElm(
    features_size       = features_size,
    hidden_size         = best_hidden_size,
    activation_function = GlobalSetting.sigmoid             ,
    fitness_function    = GlobalSetting.evaluation_function ,
    solution_size       = GlobalSetting.solution_size       ,
    trial_limit         = GlobalSetting.trial_limit         ,
    max_iteration       = GlobalSetting.max_iteration
)

# %%
results_df , convergence_df , scout_df = abc_testing(abc_elm_hidden, x_train_scaled, y_train, x_test_scaled, y_test)
results_df.describe()
# Out:
# Seed 21 start
#
# Iteration 1 end : 0.0253s | Scout Triggers: 0
# Iteration 2 end : 0.0252s | Scout Triggers: 0
# Iteration 3 end : 0.0347s | Scout Triggers: 0
# Iteration 4 end : 0.0299s | Scout Triggers: 0
# Iteration 5 end : 0.0245s | Scout Triggers: 0
# Iteration 6 end : 0.0351s | Scout Triggers: 1
# Iteration 7 end : 0.0288s | Scout Triggers: 0
# Iteration 8 end : 0.0288s | Scout Triggers: 1
# Iteration 9 end : 0.0251s | Scout Triggers: 0
# Iteration 10 end : 0.0361s | Scout Triggers: 0
# Iteration 11 end : 0.0339s | Scout Triggers: 0
# Iteration 12 end : 0.0262s | Scout Triggers: 0
# Iteration 13 end : 0.0280s | Scout Triggers: 1
# Iteration 14 end : 0.0339s | Scout Triggers: 1
# Iteration 15 end : 0.0395s | Scout Triggers: 1
# Iteration 16 end : 0.0389s | Scout Triggers: 1
# Iteration 17 end : 0.0378s | Scout Triggers: 1
# Iteration 18 end : 0.0371s | Scout Triggers: 0
# Iteration 19 end : 0.0387s | Scout Triggers: 1
# Iteration 20 end : 0.0389s | Scout Triggers: 1
#
# Seed 21 end : 0.656986s
#
#
# Seed 22 start
#
# Iteration 1 end : 0.0331s | Scout Triggers: 0
# Iteration 2 end : 0.0284s | Scout Triggers: 0
# Iteration 3 end : 0.0320s | Scout Triggers: 0
# Iteration 4 end : 0.0331s | Scout Triggers: 0
# Iteration 5 end : 0.0280s | Scout Triggers: 0
# Iteration 6 end : 0.0307s | Scout Triggers: 0
# Iteration 7 end : 0.0331s | Scout Triggers: 0
# Iteration 8 end : 0.0278s | Scout Triggers: 3
# Iteration 9 end : 0.0264s | Scout Triggers: 0
# Iteration 10 end : 0.0363s | Scout Triggers: 1
# Iteration 11 end : 0.0266s | Scout Triggers: 2
# Iteration 12 end : 0.0244s | Scout Triggers: 0
# Iteration 13 end : 0.0251s | Scout Triggers: 0
# Iteration 14 end : 0.0298s | Scout Triggers: 0
# Iteration 15 end : 0.0326s | Scout Triggers: 0
# Iteration 16 end : 0.0285s | Scout Triggers: 4
# Iteration 17 end : 0.0290s | Scout Triggers: 0
# Iteration 18 end : 0.0298s | Scout Triggers: 0
# Iteration 19 end : 0.0316s | Scout Triggers: 0
# Iteration 20 end : 0.0267s | Scout Triggers: 1
#
# Seed 22 end : 0.604840s
#
#
# Seed 23 start
#
# Iteration 1 end : 0.0306s | Scout Triggers: 0
# Iteration 2 end : 0.0282s | Scout Triggers: 0
# Iteration 3 end : 0.0265s | Scout Triggers: 0
# Iteration 4 end : 0.0318s | Scout Triggers: 0
# Iteration 5 end : 0.0376s | Scout Triggers: 2
# Iteration 6 end : 0.0267s | Scout Triggers: 2
# Iteration 7 end : 0.0266s | Scout Triggers: 2
# Iteration 8 end : 0.0244s | Scout Triggers: 0
# Iteration 9 end : 0.0307s | Scout Triggers: 0
# Iteration 10 end : 0.0257s | Scout Triggers: 0
# Iteration 11 end : 0.0275s | Scout Triggers: 0
# Iteration 12 end : 0.0332s | Scout Triggers: 1
# Iteration 13 end : 0.0265s | Scout Triggers: 1
# Iteration 14 end : 0.0339s | Scout Triggers: 1
# Iteration 15 end : 0.0254s | Scout Triggers: 1
# Iteration 16 end : 0.0374s | Scout Triggers: 1
# Iteration 17 end : 0.0313s | Scout Triggers: 0
# Iteration 18 end : 0.0255s | Scout Triggers: 0
# Iteration 19 end : 0.0260s | Scout Triggers: 1
# Iteration 20 end : 0.0270s | Scout Triggers: 1
#
# Seed 23 end : 0.593685s
#
#
# Seed 24 start
#
# Iteration 1 end : 0.0255s | Scout Triggers: 0
# Iteration 2 end : 0.0264s | Scout Triggers: 0
# Iteration 3 end : 0.0254s | Scout Triggers: 0
# Iteration 4 end : 0.0365s | Scout Triggers: 0
# Iteration 5 end : 0.0264s | Scout Triggers: 0
# Iteration 6 end : 0.0291s | Scout Triggers: 0
# Iteration 7 end : 0.0329s | Scout Triggers: 1
# Iteration 8 end : 0.0286s | Scout Triggers: 1
# Iteration 9 end : 0.0366s | Scout Triggers: 1
# Iteration 10 end : 0.0318s | Scout Triggers: 1
# Iteration 11 end : 0.0361s | Scout Triggers: 1
# Iteration 12 end : 0.0252s | Scout Triggers: 0
# Iteration 13 end : 0.0343s | Scout Triggers: 0
# Iteration 14 end : 0.0373s | Scout Triggers: 1
# Iteration 15 end : 0.0314s | Scout Triggers: 3
# Iteration 16 end : 0.0253s | Scout Triggers: 0
# Iteration 17 end : 0.0313s | Scout Triggers: 1
# Iteration 18 end : 0.0304s | Scout Triggers: 0
# Iteration 19 end : 0.0317s | Scout Triggers: 2
# Iteration 20 end : 0.0344s | Scout Triggers: 1
#
# Seed 24 end : 0.629876s
#
#
# Seed 25 start
#
# Iteration 1 end : 0.0245s | Scout Triggers: 0
# Iteration 2 end : 0.0248s | Scout Triggers: 0
# Iteration 3 end : 0.0248s | Scout Triggers: 0
# Iteration 4 end : 0.0247s | Scout Triggers: 0
# Iteration 5 end : 0.0255s | Scout Triggers: 1
# Iteration 6 end : 0.0293s | Scout Triggers: 0
# Iteration 7 end : 0.0313s | Scout Triggers: 1
# Iteration 8 end : 0.0354s | Scout Triggers: 0
# Iteration 9 end : 0.0313s | Scout Triggers: 1
# Iteration 10 end : 0.0252s | Scout Triggers: 0
# Iteration 11 end : 0.0287s | Scout Triggers: 1
# Iteration 12 end : 0.0334s | Scout Triggers: 0
# Iteration 13 end : 0.0326s | Scout Triggers: 2
# Iteration 14 end : 0.0380s | Scout Triggers: 0
# Iteration 15 end : 0.0383s | Scout Triggers: 1
# Iteration 16 end : 0.0284s | Scout Triggers: 0
# Iteration 17 end : 0.0307s | Scout Triggers: 0
# Iteration 18 end : 0.0322s | Scout Triggers: 2
# Iteration 19 end : 0.0264s | Scout Triggers: 1
# Iteration 20 end : 0.0299s | Scout Triggers: 1
#
# Seed 25 end : 0.606698s
#        Accuracy  Precision    Recall       NPV  Specificity  F1-Score  \
# count  5.000000   5.000000  5.000000  5.000000     5.000000  5.000000
# mean   0.762500   0.760167  0.768750  0.768088     0.756250  0.763251
# std    0.048664   0.045786  0.071943  0.059271     0.060111  0.050733
# min    0.718750   0.694444  0.687500  0.714286     0.656250  0.721311
# 25%    0.734375   0.757576  0.718750  0.735294     0.750000  0.735294
# 50%    0.750000   0.758621  0.781250  0.750000     0.781250  0.741935
# 75%    0.765625   0.766667  0.781250  0.774194     0.781250  0.769231
# max    0.843750   0.823529  0.875000  0.866667     0.812500  0.848485
#
#        F2-Score  Bal Accuracy       MCC   ABC_Seed
# count  5.000000      5.000000  5.000000   5.000000
# mean   0.766255      0.762500  0.526624  23.000000
# std    0.062235      0.048664  0.096760   1.581139
# min    0.700637      0.718750  0.440959  21.000000
# 25%    0.727848      0.734375  0.470824  22.000000
# 50%    0.762195      0.750000  0.500979  23.000000
# 75%    0.776398      0.765625  0.531510  24.000000
# max    0.864198      0.843750  0.688847  25.000000

# %%
Plotting.plot_abc_dashboard(convergence_df,scout_df,"Best_Hidden_Nodes",is_final_record=True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\ABC_Telemetry_Best_Hidden_Nodes_F1-Score.png
