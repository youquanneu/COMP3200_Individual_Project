# %% [markdown]
# ## Best Hidden Size

# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.GallstoneDataSet import GallstoneDataSet
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Global.Plotting import Plotting
from Pipeline.Optimization.ABC_Testing import abc_testing

# %%
gallstone_dataset = GallstoneDataSet()
gallstone_dataset.fetch_data_path_1()

features_size = gallstone_dataset.x_train_scaled.shape[1]
x_train = gallstone_dataset.x_train_scaled
x_test  = gallstone_dataset.x_test_scaled
y_train = gallstone_dataset.y_train
y_test  = gallstone_dataset.y_test

# %%
best_hidden_config = GlobalSetting.get_config_by_type("Best_Hidden_Nodes")
best_hidden_size = best_hidden_config["Hidden_Nodes"] if best_hidden_config else None

# %%
abc_elm_hidden  = ArtificialBeeColonyElmCV(
    features_size       = features_size,
    hidden_size         = best_hidden_size,
    activation_function = GlobalSetting.sigmoid             ,
    fitness_function    = GlobalSetting.evaluation_function ,
    solution_size       = GlobalSetting.solution_size       ,
    trial_limit         = GlobalSetting.trial_limit         ,
    max_iteration       = GlobalSetting.max_iteration
)

# %%
results_df , convergence_df , scout_df = abc_testing(abc_elm_hidden,x_train, y_train, x_test, y_test)
results_df.describe()
# Out:
# Seed 41 start
#
# Iteration 1 end : 0.1114s | Scout Triggers: 0
# Iteration 2 end : 0.1177s | Scout Triggers: 0
# Iteration 3 end : 0.1442s | Scout Triggers: 0
# Iteration 4 end : 0.1522s | Scout Triggers: 1
# Iteration 5 end : 0.1339s | Scout Triggers: 0
# Iteration 6 end : 0.1247s | Scout Triggers: 1
# Iteration 7 end : 0.1187s | Scout Triggers: 1
# Iteration 8 end : 0.1214s | Scout Triggers: 0
# Iteration 9 end : 0.1171s | Scout Triggers: 0
# Iteration 10 end : 0.1082s | Scout Triggers: 0
# Iteration 11 end : 0.1245s | Scout Triggers: 0
# Iteration 12 end : 0.1327s | Scout Triggers: 0
# Iteration 13 end : 0.1192s | Scout Triggers: 0
# Iteration 14 end : 0.1333s | Scout Triggers: 0
# Iteration 15 end : 0.1261s | Scout Triggers: 0
# Iteration 16 end : 0.1257s | Scout Triggers: 1
# Iteration 17 end : 0.1285s | Scout Triggers: 1
# Iteration 18 end : 0.1281s | Scout Triggers: 1
# Iteration 19 end : 0.1220s | Scout Triggers: 1
# Iteration 20 end : 0.1252s | Scout Triggers: 0
#
# Seed 41 end : 2.610462s
#
#
# Seed 42 start
#
# Iteration 1 end : 0.1068s | Scout Triggers: 0
# Iteration 2 end : 0.1270s | Scout Triggers: 0
# Iteration 3 end : 0.1155s | Scout Triggers: 0
# Iteration 4 end : 0.1211s | Scout Triggers: 0
# Iteration 5 end : 0.1133s | Scout Triggers: 0
# Iteration 6 end : 0.1254s | Scout Triggers: 1
# Iteration 7 end : 0.1155s | Scout Triggers: 0
# Iteration 8 end : 0.1252s | Scout Triggers: 0
# Iteration 9 end : 0.1056s | Scout Triggers: 0
# Iteration 10 end : 0.1149s | Scout Triggers: 0
# Iteration 11 end : 0.1296s | Scout Triggers: 1
# Iteration 12 end : 0.1125s | Scout Triggers: 0
# Iteration 13 end : 0.1286s | Scout Triggers: 1
# Iteration 14 end : 0.1172s | Scout Triggers: 1
# Iteration 15 end : 0.1388s | Scout Triggers: 1
# Iteration 16 end : 0.1313s | Scout Triggers: 0
# Iteration 17 end : 0.1416s | Scout Triggers: 0
# Iteration 18 end : 0.1293s | Scout Triggers: 0
# Iteration 19 end : 0.1335s | Scout Triggers: 1
# Iteration 20 end : 0.1273s | Scout Triggers: 0
#
# Seed 42 end : 2.529077s
#
#
# Seed 43 start
#
# Iteration 1 end : 0.1293s | Scout Triggers: 0
# Iteration 2 end : 0.1361s | Scout Triggers: 0
# Iteration 3 end : 0.1407s | Scout Triggers: 0
# Iteration 4 end : 0.1274s | Scout Triggers: 0
# Iteration 5 end : 0.1403s | Scout Triggers: 0
# Iteration 6 end : 0.1333s | Scout Triggers: 0
# Iteration 7 end : 0.1250s | Scout Triggers: 1
# Iteration 8 end : 0.1245s | Scout Triggers: 0
# Iteration 9 end : 0.1275s | Scout Triggers: 1
# Iteration 10 end : 0.1428s | Scout Triggers: 2
# Iteration 11 end : 0.1334s | Scout Triggers: 0
# Iteration 12 end : 0.1420s | Scout Triggers: 1
# Iteration 13 end : 0.1299s | Scout Triggers: 0
# Iteration 14 end : 0.1108s | Scout Triggers: 0
# Iteration 15 end : 0.1052s | Scout Triggers: 0
# Iteration 16 end : 0.1096s | Scout Triggers: 0
# Iteration 17 end : 0.1480s | Scout Triggers: 0
# Iteration 18 end : 0.1254s | Scout Triggers: 2
# Iteration 19 end : 0.1354s | Scout Triggers: 1
# Iteration 20 end : 0.1233s | Scout Triggers: 0
#
# Seed 43 end : 2.660570s
#
#
# Seed 44 start
#
# Iteration 1 end : 0.1382s | Scout Triggers: 0
# Iteration 2 end : 0.1428s | Scout Triggers: 0
# Iteration 3 end : 0.1440s | Scout Triggers: 0
# Iteration 4 end : 0.1481s | Scout Triggers: 0
# Iteration 5 end : 0.1276s | Scout Triggers: 0
# Iteration 6 end : 0.1411s | Scout Triggers: 2
# Iteration 7 end : 0.1592s | Scout Triggers: 1
# Iteration 8 end : 0.1211s | Scout Triggers: 0
# Iteration 9 end : 0.1392s | Scout Triggers: 0
# Iteration 10 end : 0.1618s | Scout Triggers: 0
# Iteration 11 end : 0.1689s | Scout Triggers: 0
# Iteration 12 end : 0.1330s | Scout Triggers: 0
# Iteration 13 end : 0.1319s | Scout Triggers: 0
# Iteration 14 end : 0.1400s | Scout Triggers: 0
# Iteration 15 end : 0.1499s | Scout Triggers: 0
# Iteration 16 end : 0.1268s | Scout Triggers: 0
# Iteration 17 end : 0.1538s | Scout Triggers: 2
# Iteration 18 end : 0.1354s | Scout Triggers: 1
# Iteration 19 end : 0.1385s | Scout Triggers: 1
# Iteration 20 end : 0.1337s | Scout Triggers: 0
#
# Seed 44 end : 2.921100s
#        Accuracy  Precision    Recall       NPV  Specificity  F1-Score  \
# count  4.000000   4.000000  4.000000  4.000000     4.000000  4.000000
# mean   0.750000   0.765710  0.726562  0.740504     0.773438  0.743562
# std    0.012758   0.038643  0.053370  0.022697     0.064424  0.015532
# min    0.734375   0.714286  0.656250  0.710526     0.687500  0.724138
# 25%    0.746094   0.753571  0.703125  0.729102     0.757812  0.737486
# 50%    0.750000   0.770430  0.734375  0.746435     0.781250  0.744102
# 75%    0.753906   0.782568  0.757812  0.757837     0.796875  0.750178
# max    0.765625   0.807692  0.781250  0.758621     0.843750  0.761905
#
#        F2-Score  Bal Accuracy       MCC   ABC_Seed
# count  4.000000      4.000000  4.000000   4.000000
# mean   0.732814      0.750000  0.503085  42.500000
# std    0.037704      0.012758  0.025090   1.290994
# min    0.681818      0.734375  0.470824  41.000000
# 25%    0.716341      0.746094  0.493440  41.750000
# 50%    0.741283      0.750000  0.505004  42.500000
# 75%    0.757756      0.753906  0.514648  43.250000
# max    0.766871      0.765625  0.531510  44.000000

# %%
Plotting.plot_abc_dashboard(convergence_df,scout_df,"Best_Hidden_Nodes",is_final_record=True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\ABC_Telemetry_Best_Hidden_Nodes_F1-Score.png
