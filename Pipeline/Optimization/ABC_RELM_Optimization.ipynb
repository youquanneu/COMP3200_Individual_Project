# %%
from Pipeline.Global.GlobalSetting import GlobalSetting

# %%
best_optimization_config = GlobalSetting.get_config_by_type("Grid_Optimization")
best_optimization_hidden_size = best_optimization_config["Hidden_Nodes"] if best_optimization_config else None
best_optimization_lambda_value = best_optimization_config["Lambda_Value"] if best_optimization_config else None

# %%
(best_optimization_hidden_size,best_optimization_lambda_value)
# Out:
# (23, 0.16150558288984576)
