# %% [markdown]
# ## Best Hidden Size CV

# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.GallstoneDataSet import GallstoneDataSet
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Global.Plotting import Plotting
from Pipeline.Optimization.ABC_Testing import abc_testing

# %%
gallstone_dataset = GallstoneDataSet()
gallstone_dataset.fetch_data_path_1()

features_size = gallstone_dataset.x_train.shape[1]
x_train = gallstone_dataset.x_train
x_test  = gallstone_dataset.x_test
y_train = gallstone_dataset.y_train
y_test  = gallstone_dataset.y_test

# %%
best_hidden_config = GlobalSetting.get_config_by_type("Best_Hidden_Nodes")
best_hidden_size = best_hidden_config["Hidden_Nodes"] if best_hidden_config else None

# %%
abc_elm_cv_hidden  = ArtificialBeeColonyElmCV(
    features_size       = features_size,
    hidden_size         = best_hidden_size,
    activation_function = GlobalSetting.sigmoid             ,
    fitness_function    = GlobalSetting.evaluation_function ,
    solution_size       = GlobalSetting.solution_size       ,
    trial_limit         = GlobalSetting.trial_limit         ,
    max_iteration       = GlobalSetting.max_iteration
)

# %%
results_df , convergence_df , scout_df = abc_testing(abc_elm_cv_hidden, x_train, y_train, x_test, y_test)
results_df.describe()
# Out:
# Seed 21 start
#
# Iteration 1 end : 0.1015s | Scout Triggers: 0
# Iteration 2 end : 0.1184s | Scout Triggers: 0
# Iteration 3 end : 0.1241s | Scout Triggers: 0
# Iteration 4 end : 0.1155s | Scout Triggers: 0
# Iteration 5 end : 0.1174s | Scout Triggers: 0
# Iteration 6 end : 0.1248s | Scout Triggers: 1
# Iteration 7 end : 0.1255s | Scout Triggers: 0
# Iteration 8 end : 0.0992s | Scout Triggers: 0
# Iteration 9 end : 0.1046s | Scout Triggers: 1
# Iteration 10 end : 0.0955s | Scout Triggers: 2
# Iteration 11 end : 0.1097s | Scout Triggers: 0
# Iteration 12 end : 0.1132s | Scout Triggers: 0
# Iteration 13 end : 0.1290s | Scout Triggers: 0
# Iteration 14 end : 0.1099s | Scout Triggers: 0
# Iteration 15 end : 0.1144s | Scout Triggers: 2
# Iteration 16 end : 0.0951s | Scout Triggers: 0
# Iteration 17 end : 0.1075s | Scout Triggers: 2
# Iteration 18 end : 0.1191s | Scout Triggers: 0
# Iteration 19 end : 0.1186s | Scout Triggers: 0
# Iteration 20 end : 0.1372s | Scout Triggers: 1
#
# Seed 21 end : 2.369388s
#
#
# Seed 22 start
#
# Iteration 1 end : 0.1306s | Scout Triggers: 0
# Iteration 2 end : 0.1269s | Scout Triggers: 0
# Iteration 3 end : 0.1050s | Scout Triggers: 0
# Iteration 4 end : 0.1176s | Scout Triggers: 1
# Iteration 5 end : 0.1030s | Scout Triggers: 0
# Iteration 6 end : 0.1099s | Scout Triggers: 0
# Iteration 7 end : 0.1040s | Scout Triggers: 0
# Iteration 8 end : 0.1281s | Scout Triggers: 1
# Iteration 9 end : 0.1230s | Scout Triggers: 0
# Iteration 10 end : 0.1305s | Scout Triggers: 0
# Iteration 11 end : 0.1293s | Scout Triggers: 0
# Iteration 12 end : 0.0945s | Scout Triggers: 0
# Iteration 13 end : 0.1171s | Scout Triggers: 0
# Iteration 14 end : 0.1250s | Scout Triggers: 2
# Iteration 15 end : 0.1278s | Scout Triggers: 1
# Iteration 16 end : 0.1164s | Scout Triggers: 0
# Iteration 17 end : 0.1227s | Scout Triggers: 1
# Iteration 18 end : 0.1064s | Scout Triggers: 0
# Iteration 19 end : 0.1396s | Scout Triggers: 1
# Iteration 20 end : 0.1265s | Scout Triggers: 1
#
# Seed 22 end : 2.472527s
#
#
# Seed 23 start
#
# Iteration 1 end : 0.1128s | Scout Triggers: 0
# Iteration 2 end : 0.1212s | Scout Triggers: 0
# Iteration 3 end : 0.0996s | Scout Triggers: 0
# Iteration 4 end : 0.1134s | Scout Triggers: 0
# Iteration 5 end : 0.1391s | Scout Triggers: 1
# Iteration 6 end : 0.1257s | Scout Triggers: 0
# Iteration 7 end : 0.0951s | Scout Triggers: 0
# Iteration 8 end : 0.1011s | Scout Triggers: 1
# Iteration 9 end : 0.1111s | Scout Triggers: 2
# Iteration 10 end : 0.1235s | Scout Triggers: 0
# Iteration 11 end : 0.1153s | Scout Triggers: 0
# Iteration 12 end : 0.1247s | Scout Triggers: 1
# Iteration 13 end : 0.1102s | Scout Triggers: 1
# Iteration 14 end : 0.1121s | Scout Triggers: 0
# Iteration 15 end : 0.1341s | Scout Triggers: 0
# Iteration 16 end : 0.1255s | Scout Triggers: 1
# Iteration 17 end : 0.1330s | Scout Triggers: 0
# Iteration 18 end : 0.1003s | Scout Triggers: 0
# Iteration 19 end : 0.1120s | Scout Triggers: 0
# Iteration 20 end : 0.1198s | Scout Triggers: 0
#
# Seed 23 end : 2.389992s
#
#
# Seed 24 start
#
# Iteration 1 end : 0.1457s | Scout Triggers: 0
# Iteration 2 end : 0.1214s | Scout Triggers: 0
# Iteration 3 end : 0.1163s | Scout Triggers: 0
# Iteration 4 end : 0.1118s | Scout Triggers: 0
# Iteration 5 end : 0.1377s | Scout Triggers: 0
# Iteration 6 end : 0.1169s | Scout Triggers: 0
# Iteration 7 end : 0.1366s | Scout Triggers: 1
# Iteration 8 end : 0.1216s | Scout Triggers: 0
# Iteration 9 end : 0.1202s | Scout Triggers: 0
# Iteration 10 end : 0.1179s | Scout Triggers: 1
# Iteration 11 end : 0.1170s | Scout Triggers: 2
# Iteration 12 end : 0.1150s | Scout Triggers: 1
# Iteration 13 end : 0.1415s | Scout Triggers: 1
# Iteration 14 end : 0.1122s | Scout Triggers: 0
# Iteration 15 end : 0.1127s | Scout Triggers: 0
# Iteration 16 end : 0.1404s | Scout Triggers: 2
# Iteration 17 end : 0.1267s | Scout Triggers: 0
# Iteration 18 end : 0.1173s | Scout Triggers: 1
# Iteration 19 end : 0.1260s | Scout Triggers: 1
# Iteration 20 end : 0.1070s | Scout Triggers: 1
#
# Seed 24 end : 2.549522s
#
#
# Seed 25 start
#
# Iteration 1 end : 0.1330s | Scout Triggers: 0
# Iteration 2 end : 0.1281s | Scout Triggers: 0
# Iteration 3 end : 0.1066s | Scout Triggers: 0
# Iteration 4 end : 0.1060s | Scout Triggers: 0
# Iteration 5 end : 0.1241s | Scout Triggers: 1
# Iteration 6 end : 0.0993s | Scout Triggers: 0
# Iteration 7 end : 0.1171s | Scout Triggers: 0
# Iteration 8 end : 0.1172s | Scout Triggers: 1
# Iteration 9 end : 0.1292s | Scout Triggers: 1
# Iteration 10 end : 0.1334s | Scout Triggers: 0
# Iteration 11 end : 0.1297s | Scout Triggers: 1
# Iteration 12 end : 0.1126s | Scout Triggers: 0
# Iteration 13 end : 0.1238s | Scout Triggers: 0
# Iteration 14 end : 0.1134s | Scout Triggers: 0
# Iteration 15 end : 0.1211s | Scout Triggers: 0
# Iteration 16 end : 0.1187s | Scout Triggers: 0
# Iteration 17 end : 0.1390s | Scout Triggers: 1
# Iteration 18 end : 0.1040s | Scout Triggers: 1
# Iteration 19 end : 0.1192s | Scout Triggers: 1
# Iteration 20 end : 0.1149s | Scout Triggers: 1
#
# Seed 25 end : 2.465806s
#        Accuracy  Precision    Recall       NPV  Specificity  F1-Score  \
# count  5.000000   5.000000  5.000000  5.000000     5.000000  5.000000
# mean   0.784375   0.791511  0.775000  0.778697     0.793750  0.782770
# std    0.057834   0.069692  0.051349  0.050834     0.071943  0.057101
# min    0.703125   0.709677  0.687500  0.696970     0.718750  0.698413
# 25%    0.765625   0.757576  0.781250  0.774194     0.750000  0.769231
# 50%    0.781250   0.781250  0.781250  0.781250     0.781250  0.781250
# 75%    0.812500   0.812500  0.812500  0.812500     0.812500  0.812500
# max    0.859375   0.896552  0.812500  0.828571     0.906250  0.852459
#
#        F2-Score  Bal Accuracy       MCC   ABC_Seed
# count  5.000000      5.000000  5.000000   5.000000
# mean   0.777999      0.784375  0.569478  23.000000
# std    0.052755      0.057834  0.116612   1.581139
# min    0.691824      0.703125  0.406449  21.000000
# 25%    0.776398      0.765625  0.531510  22.000000
# 50%    0.781250      0.781250  0.562500  23.000000
# 75%    0.812500      0.812500  0.625000  24.000000
# max    0.828025      0.859375  0.721930  25.000000

# %%
Plotting.plot_abc_dashboard(convergence_df,scout_df,"Best_Hidden_Nodes_CV",is_final_record=True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\ABC_Telemetry_Best_Hidden_Nodes_CV_F1-Score.png
