# %%
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology.ABC_Testing import cv_fold_testing

# %%
fold_id = 0
config = "Grid_Optimization"
mod = "RELM_CV"

# %%
results_df , convergence_df , scout_df = cv_fold_testing(mod, config, fold_id)
results_df.describe()
# Out:
# --- Initializing RELM_CV on Fold 0 ---
# [Data] Fold 0 loaded. Training samples: 255, Testing samples: 64
#
# Running simulation for Seed: 161...
# Iteration 100 complete | Duration: 0.5387s | Scout Triggers: 0 | Best Fitness: 0.807919
#
# Running simulation for Seed: 162...
# Iteration 100 complete | Duration: 0.4889s | Scout Triggers: 1 | Best Fitness: 0.814359
#
# Running simulation for Seed: 163...
# Iteration 100 complete | Duration: 0.5346s | Scout Triggers: 1 | Best Fitness: 0.815297
#
# Running simulation for Seed: 164...
# Iteration 100 complete | Duration: 0.4826s | Scout Triggers: 4 | Best Fitness: 0.810486
#
# Running simulation for Seed: 165...
# Iteration 100 complete | Duration: 0.4716s | Scout Triggers: 0 | Best Fitness: 0.811960
#
# Running simulation for Seed: 166...
# Iteration 100 complete | Duration: 0.5383s | Scout Triggers: 2 | Best Fitness: 0.814918
#
# Running simulation for Seed: 167...
# Iteration 100 complete | Duration: 0.4866s | Scout Triggers: 2 | Best Fitness: 0.820928
#
# Running simulation for Seed: 168...
# Iteration 100 complete | Duration: 0.4905s | Scout Triggers: 2 | Best Fitness: 0.808033
#
# Running simulation for Seed: 169...
# Iteration 100 complete | Duration: 0.5295s | Scout Triggers: 1 | Best Fitness: 0.810577
#
# Running simulation for Seed: 170...
# Iteration 100 complete | Duration: 0.4832s | Scout Triggers: 0 | Best Fitness: 0.813676
#
# Running simulation for Seed: 171...
# Iteration 100 complete | Duration: 0.5114s | Scout Triggers: 2 | Best Fitness: 0.816370
#
# Running simulation for Seed: 172...
# Iteration 100 complete | Duration: 0.5117s | Scout Triggers: 1 | Best Fitness: 0.806372
#
# Running simulation for Seed: 173...
# Iteration 100 complete | Duration: 0.4779s | Scout Triggers: 0 | Best Fitness: 0.823837
#
# Running simulation for Seed: 174...
# Iteration 100 complete | Duration: 0.5983s | Scout Triggers: 1 | Best Fitness: 0.818635
#
# Running simulation for Seed: 175...
# Iteration 100 complete | Duration: 0.4833s | Scout Triggers: 2 | Best Fitness: 0.809798
#
# Running simulation for Seed: 176...
# Iteration 100 complete | Duration: 0.5027s | Scout Triggers: 2 | Best Fitness: 0.815797
#
# Running simulation for Seed: 177...
# Iteration 100 complete | Duration: 0.5498s | Scout Triggers: 1 | Best Fitness: 0.813958
#
# Running simulation for Seed: 178...
# Iteration 100 complete | Duration: 0.4997s | Scout Triggers: 5 | Best Fitness: 0.820305
#
# Running simulation for Seed: 179...
# Iteration 100 complete | Duration: 0.4862s | Scout Triggers: 1 | Best Fitness: 0.808645
#
# Running simulation for Seed: 180...
# Iteration 100 complete | Duration: 0.4896s | Scout Triggers: 0 | Best Fitness: 0.820888
#
# Running simulation for Seed: 181...
# Iteration 100 complete | Duration: 0.5802s | Scout Triggers: 0 | Best Fitness: 0.808331
#
# Running simulation for Seed: 182...
# Iteration 100 complete | Duration: 0.4860s | Scout Triggers: 0 | Best Fitness: 0.820226
#
# Running simulation for Seed: 183...
# Iteration 100 complete | Duration: 0.5533s | Scout Triggers: 2 | Best Fitness: 0.811887
#
# Running simulation for Seed: 184...
# Iteration 100 complete | Duration: 0.5174s | Scout Triggers: 1 | Best Fitness: 0.824536
#
# Running simulation for Seed: 185...
# Iteration 100 complete | Duration: 0.4914s | Scout Triggers: 0 | Best Fitness: 0.818106
#
# Running simulation for Seed: 186...
# Iteration 100 complete | Duration: 0.4945s | Scout Triggers: 2 | Best Fitness: 0.811071
#
# Running simulation for Seed: 187...
# Iteration 100 complete | Duration: 0.4772s | Scout Triggers: 2 | Best Fitness: 0.809668
#
# Running simulation for Seed: 188...
# Iteration 100 complete | Duration: 0.5185s | Scout Triggers: 1 | Best Fitness: 0.831459
#
# Running simulation for Seed: 189...
# Iteration 100 complete | Duration: 0.5049s | Scout Triggers: 1 | Best Fitness: 0.807432
#
# Running simulation for Seed: 190...
# Iteration 100 complete | Duration: 0.4051s | Scout Triggers: 1 | Best Fitness: 0.809624
#
# [Execution] Fold 0 completed in 3144.06 seconds.
# [I/O Trace] Record exported successfully: ../../Storage/Record\Grid_Optimization_ABC_RELM_CV_Fold_0_Results.csv
# [I/O Trace] Record exported successfully: ../../Storage/Record\Grid_Optimization_ABC_RELM_CV_Fold_0_Convergence.csv
# [I/O Trace] Record exported successfully: ../../Storage/Record\Grid_Optimization_ABC_RELM_CV_Fold_0_Scout_History.csv
#         Accuracy  Precision     Recall        NPV  Specificity   F1-Score  \
# count  30.000000  30.000000  30.000000  30.000000    30.000000  30.000000
# mean    0.747917   0.791082   0.654839   0.721402     0.835354   0.715078
# std     0.037548   0.052101   0.056288   0.035844     0.051379   0.044086
# min     0.687500   0.689655   0.580645   0.675000     0.696970   0.654545
# 25%     0.718750   0.760000   0.612903   0.692308     0.818182   0.678571
# 50%     0.742188   0.795833   0.645161   0.712406     0.848485   0.708995
# 75%     0.765625   0.817340   0.677419   0.741903     0.871212   0.738057
# max     0.828125   0.913043   0.774194   0.805556     0.939394   0.813559
#
#         F2-Score  Bal Accuracy        MCC    ABC_Seed
# count  30.000000     30.000000  30.000000   30.000000
# mean    0.677385      0.745096   0.501171  175.500000
# std     0.050392      0.037638   0.076457    8.803408
# min     0.608108      0.686217   0.373899  161.000000
# 25%     0.638661      0.715543   0.441569  168.250000
# 50%     0.666667      0.740714   0.492469  175.500000
# 75%     0.703523      0.762952   0.545720  182.750000
# max     0.789474      0.826491   0.662457  190.000000

# %%
Plotting.plot_abc_dashboard(convergence_df,scout_df,f"{config}_{mod}_{fold_id}",results_df=results_df,is_final_record=True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\ABC_Telemetry_Grid_Optimization_RELM_CV_0_MCC.png
