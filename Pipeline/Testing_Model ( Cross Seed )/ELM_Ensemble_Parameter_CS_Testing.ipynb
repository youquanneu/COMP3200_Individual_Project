# %%
from Pipeline.Algorithm.ExtremeLearningMachineCVEnsemble import ExtremeLearningMachineCVEnsemble
from Pipeline.Methodology.ABC_Testing import cross_seed_testing
from Pipeline.Global.GlobalSetting import GlobalSetting

# %%
model_configs = GlobalSetting.get_model_configs()

# %%
for config in model_configs:
    result_of_model = cross_seed_testing(ExtremeLearningMachineCVEnsemble,
                                         expr_name= str(config['Model_Types']+"_CV_EnsembleCD"),
                                         model_types=config['Model_Types'],
                                         cv_folds=5,
                                         is_abc_opt=False,
                                         data_scaling=False,
                                         mod_cv_fold= 10,
                                         )
# Out:
# [I/O Trace] Record exported successfully: ../../Storage/Record\Best_Hidden_Nodes_CV_EnsembleCD_Results.csv
#
# [I/O Trace] Record exported successfully: ../../Storage/Record\Best_Lambda_CV_EnsembleCD_Results.csv
#
# [I/O Trace] Record exported successfully: ../../Storage/Record\Best_Size_and_Lambda_CV_EnsembleCD_Results.csv
#
# [I/O Trace] Record exported successfully: ../../Storage/Record\Grid_Combination_CV_EnsembleCD_Results.csv
#
# [I/O Trace] Record exported successfully: ../../Storage/Record\Grid_Optimization_CV_EnsembleCD_Results.csv
