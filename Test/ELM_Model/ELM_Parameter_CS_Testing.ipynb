# %%
from Pipeline.Algorithm.ExtremeLearningMachine import ExtremeLearningMachine
from Pipeline.Methodology.ABC_Testing import cross_seed_testing
from Pipeline.Global.GlobalSetting import GlobalSetting

# %%
model_configs = GlobalSetting.get_model_configs()

# %%
result_list = []
for config in model_configs:
    result_of_model = cross_seed_testing(ExtremeLearningMachine,
                                         expr_name      = str(config['Model_Types']),
                                         use_raw_data   = False,
                                         model_types    = config['Model_Types'],
                                         cv_folds       = 5,
                                         is_abc_opt     = False,
                                         data_scaling   = True)
    result_list.append(result_of_model)
# Out:
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.0959
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.0906
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.0988
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.0937
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.0944
#
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_Best_Hidden_Nodes_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.0562
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.0555
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.0564
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.0564
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.0563
#
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_Best_Lambda_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.0630
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.0627
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.0619
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.0616
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.0628
#
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_Best_Size_and_Lambda_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.0815
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.0884
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.0794
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.0803
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.0801
#
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_Grid_Combination_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.0543
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.0531
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.0539
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.0538
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.0536
#
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_Grid_Optimization_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.0646
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.0651
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.0648
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.0650
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.0644
#
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_Optimization_Hidden_Results.csv
