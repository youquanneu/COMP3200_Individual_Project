# %%
from Pipeline.Algorithm.ExtremeLearningMachine import ExtremeLearningMachine
from Pipeline.Methodology.ABC_Testing import cross_seed_testing
from Pipeline.Global.GlobalSetting import GlobalSetting

# %%
model_configs = GlobalSetting.get_model_configs()

# %%
for config in model_configs:
    result_of_model = cross_seed_testing(ExtremeLearningMachine,
                                         expr_name      = str(config['Model_Types']),
                                         use_raw_data   = False,
                                         model_types    = config['Model_Types'],
                                         cv_folds       = 5,
                                         is_abc_opt     = False,
                                         data_scaling   = True)
# Out:
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.0832
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.0710
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.0759
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.0854
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.0798
#
# [I/O Trace] Record exported successfully: ../../Storage/Record\Test History/cleaned_Best_Hidden_Nodes_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.0494
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.0428
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.0417
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.0419
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.0409
#
# [I/O Trace] Record exported successfully: ../../Storage/Record\Test History/cleaned_Best_Lambda_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.0406
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.0429
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.0418
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.0405
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.0432
#
# [I/O Trace] Record exported successfully: ../../Storage/Record\Test History/cleaned_Best_Size_and_Lambda_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.0725
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.0806
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.0686
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.0722
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.0674
#
# [I/O Trace] Record exported successfully: ../../Storage/Record\Test History/cleaned_Grid_Combination_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.0395
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.0418
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.0396
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.0379
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.0373
#
# [I/O Trace] Record exported successfully: ../../Storage/Record\Test History/cleaned_Grid_Optimization_Results.csv
