# %%
from Pipeline.Algorithm.ExtremeLearningMachineCVEnsemble import ExtremeLearningMachineCVEnsemble
from Pipeline.Methodology.ABC_Testing import cross_seed_testing
from Pipeline.Global.GlobalSetting import GlobalSetting

# %%
model_configs = GlobalSetting.get_model_configs()

# %%
result_list = []
for config in model_configs:
    result_of_model = cross_seed_testing(ExtremeLearningMachineCVEnsemble,
                                         expr_name      = 'Ensemble_'+str(config['Model_Types']),
                                         use_raw_data   = False,
                                         model_types    = config['Model_Types'],
                                         cv_folds       = 5,
                                         is_abc_opt     = False,
                                         data_scaling   = False,
                                         mod_cv_fold    = 9)
    result_list.append(result_of_model)
# Out:
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 1.1234
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 1.1606
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 1.1594
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 1.1542
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 1.1478
#
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_Ensemble_Best_Hidden_Nodes_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.7977
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.7873
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.7855
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.7859
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.7875
#
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_Ensemble_Best_Lambda_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.8571
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.8618
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.8522
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.8524
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.8543
#
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_Ensemble_Best_Size_and_Lambda_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 1.0739
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 1.0367
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 1.0693
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 1.0683
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 1.0687
#
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_Ensemble_Grid_Combination_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.7681
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.7645
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.7645
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.7667
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.7821
#
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_Ensemble_Grid_Optimization_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.8608
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.8666
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.8678
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.8718
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.8633
#
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_Ensemble_Optimization_Hidden_Results.csv
