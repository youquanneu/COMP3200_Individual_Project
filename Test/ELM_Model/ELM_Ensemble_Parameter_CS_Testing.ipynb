# %%
from Pipeline.Algorithm.ExtremeLearningMachineCVEnsemble import ExtremeLearningMachineCVEnsemble
from Pipeline.Methodology.ABC_Testing import cross_seed_testing
from Pipeline.Global.GlobalSetting import GlobalSetting

# %%
model_configs = GlobalSetting.get_model_configs()

# %%
for config in model_configs:
    result_of_model = cross_seed_testing(ExtremeLearningMachineCVEnsemble,
                                         expr_name      = 'Ensemble_'+str(config['Model_Types']),
                                         use_raw_data   = False,
                                         model_types    = config['Model_Types'],
                                         cv_folds       = 5,
                                         is_abc_opt     = False,
                                         data_scaling   = False,
                                         mod_cv_fold    = 9)
# Out:
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.7076
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.7115
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.7036
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.7062
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.7113
#
# [I/O Trace] Record exported successfully: ../../Storage/Record\Test History/cleaned_Ensemble_Best_Hidden_Nodes_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.5002
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.4982
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.5018
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.5136
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.5238
#
# [I/O Trace] Record exported successfully: ../../Storage/Record\Test History/cleaned_Ensemble_Best_Lambda_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.5012
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.5115
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.5233
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.5521
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.5018
#
# [I/O Trace] Record exported successfully: ../../Storage/Record\Test History/cleaned_Ensemble_Best_Size_and_Lambda_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.7669
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.7237
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.7186
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.7178
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.7147
#
# [I/O Trace] Record exported successfully: ../../Storage/Record\Test History/cleaned_Ensemble_Grid_Combination_Results.csv
#
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 0.4902
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 0.4860
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 0.5008
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 0.5202
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 0.4967
#
# [I/O Trace] Record exported successfully: ../../Storage/Record\Test History/cleaned_Ensemble_Grid_Optimization_Results.csv
