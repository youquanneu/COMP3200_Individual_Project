# %%
import multiprocessing
import os

from sklearn.ensemble import HistGradientBoostingClassifier, RandomForestClassifier

from Pipeline.Methodology.EvaluationBaseline import EvaluationBaseline

# %%
os.environ["LOKY_MAX_CPU_COUNT"] = str(multiprocessing.cpu_count()-2)

# %%
UNSCALED_REGISTRY = {
    "HGBC": {
        "model_class": HistGradientBoostingClassifier,
        "tuning_grid": {
            "learning_rate": [0.05, 0.1, 0.2],
            "max_iter": [100, 200, 500],
            "max_leaf_nodes": [15, 31, 63],
            "min_samples_leaf": [20, 50],
            "l2_regularization": [0.0, 0.1, 1.0]
        },
        "base_kwargs": {
            "early_stopping": True,
            "class_weight": "balanced"
        }
    },

    "RF": {
        "model_class": RandomForestClassifier,
        "tuning_grid": {
            "n_estimators": [100, 200],
            "max_depth": [10, 20, None],
            "min_samples_split": [2, 5, 10],
            "min_samples_leaf": [1, 2, 4],
            "max_features": ["sqrt", "log2"]
        },
        "base_kwargs": {
            "class_weight": "balanced",
            "n_jobs": 1
        }
    }
}

# %%
evaluator = EvaluationBaseline(
    UNSCALED_REGISTRY,
    use_raw_data = False,
    data_scaling = False,
    cv_folds     = 5
)

# %%
result_list = evaluator.baseline_pipeline_running()
# Out:
# [Parallel] Tuning HGBC...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 14 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:   40.3s
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 162 out of 162 | elapsed:  2.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 14 concurrent workers.
# [Parallel] Tuning RF...
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 103 out of 108 | elapsed:  7.9min remaining:   22.8s
# [Parallel(n_jobs=-1)]: Done 108 out of 108 | elapsed:  8.2min finished
# Testing - Fold 0
#
#
# Testing - Fold 0 Completed in 20.1338
#
# Testing - Fold 1
#
#
# Testing - Fold 1 Completed in 17.8182
#
# Testing - Fold 2
#
#
# Testing - Fold 2 Completed in 18.6862
#
# Testing - Fold 3
#
#
# Testing - Fold 3 Completed in 19.1011
#
# Testing - Fold 4
#
#
# Testing - Fold 4 Completed in 17.9527
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_HGBC_Results.csv
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_RF_Results.csv
