# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCVEnsemble import ArtificialBeeColonyElmCVEnsemble
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Methodology.ABC_Testing import cross_seed_testing

# %%
model_configs = GlobalSetting.get_model_configs()
config = next(item for item in model_configs if item['Model_Types'] == 'Grid_Optimization')
solution_size = 80
trial_limit   = round(80 * 1.5)
max_iteration = 120
model_name = f"ABC_RELM_CV_Ensemble_Algo_3_2_{solution_size}SN_{max_iteration}MI"

# %%
result_of_model = cross_seed_testing(ArtificialBeeColonyElmCVEnsemble,
                                     expr_name      = model_name,
                                     use_raw_data   = False,
                                     model_types    = config['Model_Types'],
                                     cv_folds       = 5,
                                     is_abc_opt     = True,
                                     data_scaling   = False,
                                     force_sn       = solution_size,
                                     force_tl       = trial_limit,
                                     force_mi       = max_iteration,
                                     employed_bee_algo3 = True,
                                     onlooker_bee_algo3 = False)
# Out:
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_ABC_RELM_CV_Ensemble_Algo_3_2_80SN_120MI_Results.csv
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test Convergence History/cleaned_ABC_RELM_CV_Ensemble_Algo_3_2_80SN_120MI_Convergence.csv
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test Scout History/cleaned_ABC_RELM_CV_Ensemble_Algo_3_2_80SN_120MI_Scout_History.csv

# %%
df_result , df_con , df_sco = result_of_model
df_result.describe()
# Out:
#        Hidden_Nodes  Lambda_Value  Solution_Size  Trial_Limit  Max_Iteration  \
# count         250.0  2.500000e+02          250.0        250.0          250.0
# mean           30.0  1.767767e-01           80.0        120.0          120.0
# std             0.0  8.065264e-16            0.0          0.0            0.0
# min            30.0  1.767767e-01           80.0        120.0          120.0
# 25%            30.0  1.767767e-01           80.0        120.0          120.0
# 50%            30.0  1.767767e-01           80.0        120.0          120.0
# 75%            30.0  1.767767e-01           80.0        120.0          120.0
# max            30.0  1.767767e-01           80.0        120.0          120.0
#
#           Fold_ID          Seed    Accuracy   Precision      Recall  \
# count  250.000000    250.000000  250.000000  250.000000  250.000000
# mean     2.000000  54127.780000    0.794533    0.846991    0.715294
# std      1.417051  27764.658417    0.050191    0.064518    0.065860
# min      0.000000   6408.000000    0.650794    0.666667    0.516129
# 25%      1.000000  35469.000000    0.762835    0.800000    0.677419
# 50%      2.000000  55003.500000    0.796875    0.851852    0.718750
# 75%      3.000000  77844.000000    0.828125    0.892857    0.774194
# max      4.000000  97525.000000    0.906250    0.961538    0.903226
#
#               NPV  Specificity    F1-Score    F2-Score  Bal Accuracy  \
# count  250.000000   250.000000  250.000000  250.000000    250.000000
# mean     0.759650     0.871822    0.774118    0.737443      0.793558
# std      0.048948     0.057821    0.056378    0.061214      0.050161
# min      0.625000     0.718750    0.592593    0.544218      0.648690
# 25%      0.725568     0.843750    0.741039    0.695364      0.761555
# 50%      0.763158     0.875000    0.777778    0.741935      0.796875
# 75%      0.794872     0.909091    0.819672    0.784314      0.828125
# max      0.906250     0.969697    0.903226    0.903226      0.905181
#
#               MCC
# count  250.000000
# mean     0.596747
# std      0.101488
# min      0.302460
# 25%      0.533600
# 50%      0.603291
# 75%      0.672538
# max      0.813549
