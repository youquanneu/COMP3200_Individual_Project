# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Methodology.ABC_Testing import cross_seed_testing

# %%
model_configs = GlobalSetting.get_model_configs()
config = next(item for item in model_configs if item['Model_Types'] == 'Grid_Optimization')
solution_size = 80
max_iteration = 120
model_name = f"ABC_RELM_CV_Algo_3_2_{solution_size}SN_{max_iteration}MI"

# %%
result_of_model = cross_seed_testing(ArtificialBeeColonyElmCV,
                                     expr_name      = model_name,
                                     use_raw_data   = False,
                                     model_types    = config['Model_Types'],
                                     cv_folds       = 5,
                                     is_abc_opt     = True,
                                     data_scaling   = False,
                                     force_sn       = solution_size,
                                     force_mi       = max_iteration,
                                     employed_bee_algo3 = True,
                                     onlooker_bee_algo3 = False)
# Out:
# Testing - Fold 0
# Seed 82758  | Iteration 120 complete | Duration: 0.1733s | Scout Triggers: 0 | Best Fitness: 0.849757
#
# Testing - Fold 0 Completed in 2254.8199
#
# Testing - Fold 1
# Seed 82758  | Iteration 120 complete | Duration: 0.2452s | Scout Triggers: 2 | Best Fitness: 0.855270
#
# Testing - Fold 1 Completed in 2256.2782
#
# Testing - Fold 2
# Seed 82758  | Iteration 120 complete | Duration: 0.3099s | Scout Triggers: 0 | Best Fitness: 0.879243
#
# Testing - Fold 2 Completed in 2804.7673
#
# Testing - Fold 3
# Seed 82758  | Iteration 120 complete | Duration: 0.1883s | Scout Triggers: 1 | Best Fitness: 0.865976
#
# Testing - Fold 3 Completed in 2478.5163
#
# Testing - Fold 4
# Seed 82758  | Iteration 120 complete | Duration: 0.1809s | Scout Triggers: 3 | Best Fitness: 0.846218
#
# Testing - Fold 4 Completed in 2005.5844
#
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_ABC_RELM_CV_Algo_3_2_80SN_120MI_Results.csv
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test Convergence History/cleaned_ABC_RELM_CV_Algo_3_2_80SN_120MI_Convergence.csv
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test Scout History/cleaned_ABC_RELM_CV_Algo_3_2_80SN_120MI_Scout_History.csv

# %%
df_result , df_con , df_sco = result_of_model
df_result.describe()
# Out:
#        Hidden_Nodes  Lambda_Value  Solution_Size  Trial_Limit  Max_Iteration  \
# count         250.0  2.500000e+02          250.0        250.0          250.0
# mean           30.0  1.767767e-01           80.0         40.0          120.0
# std             0.0  8.065264e-16            0.0          0.0            0.0
# min            30.0  1.767767e-01           80.0         40.0          120.0
# 25%            30.0  1.767767e-01           80.0         40.0          120.0
# 50%            30.0  1.767767e-01           80.0         40.0          120.0
# 75%            30.0  1.767767e-01           80.0         40.0          120.0
# max            30.0  1.767767e-01           80.0         40.0          120.0
#
#           Fold_ID          Seed    Accuracy   Precision      Recall  \
# count  250.000000    250.000000  250.000000  250.000000  250.000000
# mean     2.000000  54127.780000    0.795593    0.851951    0.711673
# std      1.417051  27764.658417    0.048718    0.062837    0.064129
# min      0.000000   6408.000000    0.666667    0.678571    0.548387
# 25%      1.000000  35469.000000    0.762835    0.815657    0.661542
# 50%      2.000000  55003.500000    0.796875    0.857143    0.718750
# 75%      3.000000  77844.000000    0.828125    0.888889    0.750000
# max      4.000000  97525.000000    0.890625    1.000000    0.870968
#
#               NPV  Specificity    F1-Score    F2-Score  Bal Accuracy  \
# count  250.000000   250.000000  250.000000  250.000000    250.000000
# mean     0.758435     0.877409    0.774135    0.735152      0.794541
# std      0.046878     0.055664    0.055309    0.059827      0.048673
# min      0.641026     0.718750    0.618182    0.574324      0.664819
# 25%      0.722222     0.843750    0.737247    0.691933      0.761845
# 50%      0.763158     0.875000    0.780456    0.743243      0.796875
# 75%      0.794118     0.909091    0.813559    0.780743      0.828125
# max      0.870968     1.000000    0.877193    0.865385      0.888074
#
#               MCC
# count  250.000000
# mean     0.599588
# std      0.098469
# min      0.333678
# 25%      0.535496
# 50%      0.616900
# 75%      0.665795
# max      0.799193
