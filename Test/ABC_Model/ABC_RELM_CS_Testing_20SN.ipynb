# %%
from Pipeline.Algorithm.ArtificialBeeColonyElm import ArtificialBeeColonyElm
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Methodology.ABC_Testing import cross_seed_testing

# %%
model_configs = GlobalSetting.get_model_configs()
config = next(item for item in model_configs if item['Model_Types'] == 'Grid_Optimization')
solution_size = 20
max_iteration = 100
model_name = f"ABC_RELM_Algo_2_2_{solution_size}SN_{max_iteration}MI"

# %%
result_of_model = cross_seed_testing(ArtificialBeeColonyElm,
                                     expr_name      = model_name,
                                     use_raw_data   = False,
                                     model_types    = config['Model_Types'],
                                     cv_folds       = 5,
                                     is_abc_opt     = True,
                                     data_scaling   = True,
                                     force_sn       = solution_size,
                                     force_mi       = max_iteration,
                                     employed_bee_algo3 = False,
                                     onlooker_bee_algo3 = False)
# Out:
# Testing - Fold 0
# Seed 130  | Iteration 100 complete | Duration: 0.0201s | Scout Triggers: 1 | Best Fitness: 0.899985
#
# Testing - Fold 0 Completed in 60.4679
#
# Testing - Fold 1
# Seed 130  | Iteration 100 complete | Duration: 0.0185s | Scout Triggers: 0 | Best Fitness: 0.912155
#
# Testing - Fold 1 Completed in 61.9810
#
# Testing - Fold 2
# Seed 130  | Iteration 100 complete | Duration: 0.0182s | Scout Triggers: 1 | Best Fitness: 0.910852
#
# Testing - Fold 2 Completed in 59.6587
#
# Testing - Fold 3
# Seed 130  | Iteration 100 complete | Duration: 0.0198s | Scout Triggers: 3 | Best Fitness: 0.918613
#
# Testing - Fold 3 Completed in 59.5638
#
# Testing - Fold 4
# Seed 130  | Iteration 100 complete | Duration: 0.0182s | Scout Triggers: 0 | Best Fitness: 0.889570
#
# Testing - Fold 4 Completed in 59.9000
#
# [I/O Trace] Record exported successfully: ../../Storage/Record\Test History/cleaned_ABC_RELM_Algo_2_2_20SN_100MI_Results.csv
# [I/O Trace] Record exported successfully: ../../Storage/Record\Test Convergence History/cleaned_ABC_RELM_Algo_2_2_20SN_100MI_Convergence.csv
# [I/O Trace] Record exported successfully: ../../Storage/Record\Test Scout History/cleaned_ABC_RELM_Algo_2_2_20SN_100MI_Scout_History.csv

# %%
df_result , df_con , df_sco = result_of_model
df_result.describe()
# Out:
#        Hidden_Nodes  Lambda_Value  Solution_Size  Trial_Limit  Max_Iteration  \
# count         150.0      150.0000          150.0        150.0          150.0
# mean           30.0        0.0625           20.0         10.0          100.0
# std             0.0        0.0000            0.0          0.0            0.0
# min            30.0        0.0625           20.0         10.0          100.0
# 25%            30.0        0.0625           20.0         10.0          100.0
# 50%            30.0        0.0625           20.0         10.0          100.0
# 75%            30.0        0.0625           20.0         10.0          100.0
# max            30.0        0.0625           20.0         10.0          100.0
#
#           Fold_ID        Seed    Accuracy   Precision      Recall         NPV  \
# count  150.000000  150.000000  150.000000  150.000000  150.000000  150.000000
# mean     2.000000  115.500000    0.791308    0.839388    0.715921    0.759160
# std      1.418951    8.684438    0.045861    0.055788    0.067742    0.047276
# min      0.000000  101.000000    0.650794    0.692308    0.516129    0.625000
# 25%      1.000000  108.000000    0.762835    0.800000    0.677419    0.729730
# 50%      2.000000  115.500000    0.795263    0.846154    0.718750    0.763158
# 75%      3.000000  123.000000    0.828125    0.880000    0.750000    0.787879
# max      4.000000  130.000000    0.890625    0.962963    0.906250    0.903226
#
#        Specificity    F1-Score    F2-Score  Bal Accuracy         MCC
# count   150.000000  150.000000  150.000000    150.000000  150.000000
# mean      0.864640    0.771168    0.736733      0.790280    0.589442
# std       0.052382    0.053506    0.061390      0.045940    0.091777
# min       0.687500    0.592593    0.544218      0.648690    0.308796
# 25%       0.843750    0.740741    0.696523      0.762223    0.533600
# 50%       0.875000    0.775986    0.742589      0.793255    0.593882
# 75%       0.906250    0.811924    0.779221      0.826002    0.657822
# max       0.968750    0.892308    0.900621      0.890625    0.790965
