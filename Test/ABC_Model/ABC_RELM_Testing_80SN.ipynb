# %%
from Pipeline.Algorithm.ArtificialBeeColonyElm import ArtificialBeeColonyElm
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Methodology.ABC_Testing import cross_seed_testing

# %%
model_configs = GlobalSetting.get_model_configs()
config = next(item for item in model_configs if item['Model_Types'] == 'Grid_Optimization')
solution_size = 80
max_iteration = 120
model_name = f"ABC_RELM_Algo_3_2_{solution_size}SN_{max_iteration}MI"

# %%
result_of_model = cross_seed_testing(ArtificialBeeColonyElm,
                                     expr_name      = model_name,
                                     use_raw_data   = False,
                                     model_types    = config['Model_Types'],
                                     cv_folds       = 5,
                                     is_abc_opt     = True,
                                     data_scaling   = True,
                                     force_sn       = solution_size,
                                     force_mi       = max_iteration,
                                     employed_bee_algo3 = True,
                                     onlooker_bee_algo3 = False)
# Out:
# Testing - Fold 0
# Seed 82758  | Iteration 120 complete | Duration: 0.0441s | Scout Triggers: 0 | Best Fitness: 0.915844
#
# Testing - Fold 0 Completed in 476.5426
#
# Testing - Fold 1
# Seed 82758  | Iteration 120 complete | Duration: 0.0485s | Scout Triggers: 0 | Best Fitness: 0.915758
#
# Testing - Fold 1 Completed in 495.6552
#
# Testing - Fold 2
# Seed 82758  | Iteration 120 complete | Duration: 0.0636s | Scout Triggers: 0 | Best Fitness: 0.916526
#
# Testing - Fold 2 Completed in 570.3000
#
# Testing - Fold 3
# Seed 82758  | Iteration 120 complete | Duration: 0.0451s | Scout Triggers: 2 | Best Fitness: 0.930199
#
# Testing - Fold 3 Completed in 521.1215
#
# Testing - Fold 4
# Seed 82758  | Iteration 120 complete | Duration: 0.0454s | Scout Triggers: 3 | Best Fitness: 0.903355
#
# Testing - Fold 4 Completed in 489.5706
#
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_ABC_RELM_Algo_3_2_80SN_120MI_Results.csv
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test Convergence History/cleaned_ABC_RELM_Algo_3_2_80SN_120MI_Convergence.csv
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test Scout History/cleaned_ABC_RELM_Algo_3_2_80SN_120MI_Scout_History.csv

# %%
df_result , df_con , df_sco = result_of_model
df_result.describe()
# Out:
#        Hidden_Nodes  Lambda_Value  Solution_Size  Trial_Limit  Max_Iteration  \
# count         250.0  2.500000e+02          250.0        250.0          250.0
# mean           30.0  1.767767e-01           80.0         40.0          120.0
# std             0.0  8.065264e-16            0.0          0.0            0.0
# min            30.0  1.767767e-01           80.0         40.0          120.0
# 25%            30.0  1.767767e-01           80.0         40.0          120.0
# 50%            30.0  1.767767e-01           80.0         40.0          120.0
# 75%            30.0  1.767767e-01           80.0         40.0          120.0
# max            30.0  1.767767e-01           80.0         40.0          120.0
#
#           Fold_ID          Seed    Accuracy   Precision      Recall  \
# count  250.000000    250.000000  250.000000  250.000000  250.000000
# mean     2.000000  54127.780000    0.795587    0.849220    0.715153
# std      1.417051  27764.658417    0.044806    0.058504    0.061922
# min      0.000000   6408.000000    0.666667    0.692308    0.580645
# 25%      1.000000  35469.000000    0.765625    0.814815    0.677419
# 50%      2.000000  55003.500000    0.796875    0.851852    0.718750
# 75%      3.000000  77844.000000    0.828125    0.888889    0.774194
# max      4.000000  97525.000000    0.875000    1.000000    0.870968
#
#               NPV  Specificity    F1-Score    F2-Score  Bal Accuracy  \
# count  250.000000   250.000000  250.000000  250.000000    250.000000
# mean     0.760040     0.873981    0.774956    0.737652      0.794567
# std      0.044025     0.053887    0.051076    0.056769      0.044751
# min      0.648649     0.687500    0.631579    0.600000      0.665323
# 25%      0.727887     0.843750    0.740741    0.700000      0.765625
# 50%      0.763158     0.875000    0.779661    0.743243      0.796875
# 75%      0.800000     0.906250    0.814501    0.784314      0.827961
# max      0.870968     1.000000    0.866667    0.865385      0.875000
#
#               MCC
# count  250.000000
# mean     0.599062
# std      0.090292
# min      0.335761
# 25%      0.537856
# 50%      0.601133
# 75%      0.665795
# max      0.763542
