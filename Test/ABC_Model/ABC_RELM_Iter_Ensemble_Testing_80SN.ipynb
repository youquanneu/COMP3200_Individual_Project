# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmIterEnsemble import ArtificialBeeColonyElmIterEnsemble
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Methodology.ABC_Testing import cross_seed_testing

# %%
model_configs = GlobalSetting.get_model_configs()
config = next(item for item in model_configs if item['Model_Types'] == 'Grid_Optimization')
solution_size = 80
trial_limit   = round(80 * 1.5)
max_iteration = 120
model_name = f"ABC_RELM_Iter_Ensemble_Algo_3_2_{solution_size}SN_{max_iteration}MI"

# %%
result_of_model = cross_seed_testing(ArtificialBeeColonyElmIterEnsemble,
                                     expr_name      = model_name,
                                     use_raw_data   = False,
                                     model_types    = config['Model_Types'],
                                     cv_folds       = 5,
                                     is_abc_opt     = True,
                                     data_scaling   = False,
                                     force_sn       = solution_size,
                                     force_tl       = trial_limit,
                                     force_mi       = max_iteration,
                                     employed_bee_algo3 = True,
                                     onlooker_bee_algo3 = False)
# Out:
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test History/cleaned_ABC_RELM_Iter_Ensemble_Algo_3_2_80SN_120MI_Results.csv
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test Convergence History/cleaned_ABC_RELM_Iter_Ensemble_Algo_3_2_80SN_120MI_Convergence.csv
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Test Scout History/cleaned_ABC_RELM_Iter_Ensemble_Algo_3_2_80SN_120MI_Scout_History.csv

# %%
df_result , df_con , df_sco = result_of_model
df_result.describe()
# Out:
#        Hidden_Nodes  Lambda_Value  Solution_Size  Trial_Limit  Max_Iteration  \
# count         250.0  2.500000e+02          250.0        250.0          250.0
# mean           30.0  1.767767e-01           80.0        120.0          120.0
# std             0.0  8.065264e-16            0.0          0.0            0.0
# min            30.0  1.767767e-01           80.0        120.0          120.0
# 25%            30.0  1.767767e-01           80.0        120.0          120.0
# 50%            30.0  1.767767e-01           80.0        120.0          120.0
# 75%            30.0  1.767767e-01           80.0        120.0          120.0
# max            30.0  1.767767e-01           80.0        120.0          120.0
#
#           Fold_ID          Seed    Accuracy   Precision      Recall  \
# count  250.000000    250.000000  250.000000  250.000000  250.000000
# mean     2.000000  54127.780000    0.794906    0.846658    0.716032
# std      1.417051  27764.658417    0.049058    0.061507    0.065357
# min      0.000000   6408.000000    0.634921    0.666667    0.516129
# 25%      1.000000  35469.000000    0.762835    0.800000    0.677419
# 50%      2.000000  55003.500000    0.796875    0.851852    0.709677
# 75%      3.000000  77844.000000    0.828125    0.888889    0.774194
# max      4.000000  97525.000000    0.906250    0.961538    0.870968
#
#               NPV  Specificity    F1-Score    F2-Score  Bal Accuracy  \
# count  250.000000   250.000000  250.000000  250.000000    250.000000
# mean     0.760186     0.871848    0.774541    0.738089      0.793940
# std      0.048339     0.054565    0.055567    0.060716      0.049064
# min      0.615385     0.718750    0.581818    0.540541      0.633065
# 25%      0.725000     0.843750    0.739031    0.696523      0.761555
# 50%      0.763158     0.875000    0.778719    0.738255      0.796875
# 75%      0.798718     0.906250    0.813559    0.789474      0.828125
# max      0.885714     0.969697    0.900000    0.882353      0.905181
#
#               MCC
# count  250.000000
# mean     0.597243
# std      0.098911
# min      0.273975
# 25%      0.535228
# 50%      0.603291
# 75%      0.671911
# max      0.813549
