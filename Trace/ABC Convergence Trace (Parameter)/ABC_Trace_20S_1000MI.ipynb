# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 1000
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 1000 complete | Duration: 0.1655s | Scout Triggers: 8 | Best Fitness: 0.831757 | Val Fitness: 0.823575
#
# Tracing - Fold 0 Completed in 4975.9064
#
# Tracing - Fold 1
# Seed 160  | Iteration 1000 complete | Duration: 0.1796s | Scout Triggers: 4 | Best Fitness: 0.834232 | Val Fitness: 0.852343
#
# Tracing - Fold 1 Completed in 4660.6738
#
# Tracing - Fold 2
# Seed 160  | Iteration 1000 complete | Duration: 0.1569s | Scout Triggers: 4 | Best Fitness: 0.888791 | Val Fitness: 0.829226
#
# Tracing - Fold 2 Completed in 4316.3452
#
# Tracing - Fold 3
# Seed 160  | Iteration 1000 complete | Duration: 0.1499s | Scout Triggers: 2 | Best Fitness: 0.902576 | Val Fitness: 0.805085
#
# Tracing - Fold 3 Completed in 4667.3814
#
# Tracing - Fold 4
# Seed 160  | Iteration 1000 complete | Duration: 0.1260s | Scout Triggers: 4 | Best Fitness: 0.843191 | Val Fitness: 0.764615
#
# Tracing - Fold 4 Completed in 4530.0321
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_1000MI_Trace.csv
