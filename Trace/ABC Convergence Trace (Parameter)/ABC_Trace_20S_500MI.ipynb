# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 500
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 500 complete | Duration: 0.1549s | Scout Triggers: 4 | Best Fitness: 0.830241 | Val Fitness: 0.846917
#
# Tracing - Fold 0 Completed in 1933.8294
#
# Tracing - Fold 1
# Seed 160  | Iteration 500 complete | Duration: 0.1498s | Scout Triggers: 2 | Best Fitness: 0.857959 | Val Fitness: 0.846917
#
# Tracing - Fold 1 Completed in 1854.1593
#
# Tracing - Fold 2
# Seed 160  | Iteration 500 complete | Duration: 0.0802s | Scout Triggers: 3 | Best Fitness: 0.867387 | Val Fitness: 0.864923
#
# Tracing - Fold 2 Completed in 1549.1012
#
# Tracing - Fold 3
# Seed 160  | Iteration 500 complete | Duration: 0.0818s | Scout Triggers: 2 | Best Fitness: 0.895199 | Val Fitness: 0.764615
#
# Tracing - Fold 3 Completed in 1218.2554
#
# Tracing - Fold 4
# Seed 160  | Iteration 500 complete | Duration: 0.0809s | Scout Triggers: 3 | Best Fitness: 0.826561 | Val Fitness: 0.8438999
#
# Tracing - Fold 4 Completed in 1237.2390
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_500MI_Trace.csv
