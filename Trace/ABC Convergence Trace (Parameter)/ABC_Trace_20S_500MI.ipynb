# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 500
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 500 complete | Duration: 0.1033s | Scout Triggers: 2 | Best Fitness: 0.855071 | Val Fitness: 0.8292263
#
# Tracing - Fold 0 Completed in 1718.3663
#
# Tracing - Fold 1
# Seed 160  | Iteration 500 complete | Duration: 0.0953s | Scout Triggers: 4 | Best Fitness: 0.831851 | Val Fitness: 0.804485
#
# Tracing - Fold 1 Completed in 1521.2501
#
# Tracing - Fold 2
# Seed 160  | Iteration 500 complete | Duration: 0.0991s | Scout Triggers: 6 | Best Fitness: 0.866715 | Val Fitness: 0.843899
#
# Tracing - Fold 2 Completed in 1372.8014
#
# Tracing - Fold 3
# Seed 160  | Iteration 500 complete | Duration: 0.0849s | Scout Triggers: 4 | Best Fitness: 0.901194 | Val Fitness: 0.7453854
#
# Tracing - Fold 3 Completed in 1252.4324
#
# Tracing - Fold 4
# Seed 160  | Iteration 500 complete | Duration: 0.0822s | Scout Triggers: 2 | Best Fitness: 0.827573 | Val Fitness: 0.8253257
#
# Tracing - Fold 4 Completed in 1234.8699
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_500MI_Trace.csv
