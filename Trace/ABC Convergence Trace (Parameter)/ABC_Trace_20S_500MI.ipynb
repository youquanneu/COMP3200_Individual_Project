# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 500
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 500 complete | Duration: 0.0798s | Scout Triggers: 1 | Best Fitness: 0.820521 | Val Fitness: 0.843899
#
# Tracing - Fold 0 Completed in 1316.7248
#
# Tracing - Fold 1
# Seed 160  | Iteration 500 complete | Duration: 0.0765s | Scout Triggers: 2 | Best Fitness: 0.823989 | Val Fitness: 0.825325
#
# Tracing - Fold 1 Completed in 1221.8543
#
# Tracing - Fold 2
# Seed 160  | Iteration 500 complete | Duration: 0.0756s | Scout Triggers: 1 | Best Fitness: 0.843372 | Val Fitness: 0.825325
#
# Tracing - Fold 2 Completed in 1155.9521
#
# Tracing - Fold 3
# Seed 160  | Iteration 500 complete | Duration: 0.0774s | Scout Triggers: 3 | Best Fitness: 0.874582 | Val Fitness: 0.784284
#
# Tracing - Fold 3 Completed in 1130.5572
#
# Tracing - Fold 4
# Seed 160  | Iteration 500 complete | Duration: 0.0792s | Scout Triggers: 4 | Best Fitness: 0.809726 | Val Fitness: 0.823846
#
# Tracing - Fold 4 Completed in 1134.7855
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_500MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_20SN_10TL_500MI_MCC.png
