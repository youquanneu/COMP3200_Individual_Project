# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.0874s | Scout Triggers: 1 | Best Fitness: 0.827138 | Val Fitness: 0.789057
#
# Tracing - Fold 0 Completed in 272.0810
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.0934s | Scout Triggers: 3 | Best Fitness: 0.822222 | Val Fitness: 0.785727
#
# Tracing - Fold 1 Completed in 268.8157
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.0881s | Scout Triggers: 3 | Best Fitness: 0.841011 | Val Fitness: 0.785727
#
# Tracing - Fold 2 Completed in 268.8790
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.0837s | Scout Triggers: 1 | Best Fitness: 0.881845 | Val Fitness: 0.764615
#
# Tracing - Fold 3 Completed in 270.1276
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.0924s | Scout Triggers: 2 | Best Fitness: 0.807299 | Val Fitness: 0.825325
#
# Tracing - Fold 4 Completed in 269.2503
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_100MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_20SN_10TL_100MI_MCC.png
