# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.1090s | Scout Triggers: 3 | Best Fitness: 0.818721 | Val Fitness: 0.818953
#
# Tracing - Fold 0 Completed in 335.5151
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.1163s | Scout Triggers: 8 | Best Fitness: 0.831409 | Val Fitness: 0.876588
#
# Tracing - Fold 1 Completed in 353.0867
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.1167s | Scout Triggers: 1 | Best Fitness: 0.835577 | Val Fitness: 0.829226
#
# Tracing - Fold 2 Completed in 348.6157
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.0978s | Scout Triggers: 1 | Best Fitness: 0.865988 | Val Fitness: 0.804485
#
# Tracing - Fold 3 Completed in 339.5410
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.1171s | Scout Triggers: 5 | Best Fitness: 0.814492 | Val Fitness: 0.844376
#
# Tracing - Fold 4 Completed in 339.3190
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_100MI_Trace.csv
