# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.1523s | Scout Triggers: 2 | Best Fitness: 0.833506 | Val Fitness: 0.785727
#
# Tracing - Fold 0 Completed in 373.3508
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.1167s | Scout Triggers: 2 | Best Fitness: 0.832146 | Val Fitness: 0.864923
#
# Tracing - Fold 1 Completed in 384.5347
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.1197s | Scout Triggers: 4 | Best Fitness: 0.849470 | Val Fitness: 0.883312
#
# Tracing - Fold 2 Completed in 361.8936
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.1280s | Scout Triggers: 5 | Best Fitness: 0.847661 | Val Fitness: 0.784615
#
# Tracing - Fold 3 Completed in 413.8404
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.1342s | Scout Triggers: 6 | Best Fitness: 0.809372 | Val Fitness: 0.804485
#
# Tracing - Fold 4 Completed in 413.5933
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_100MI_Trace.csv
