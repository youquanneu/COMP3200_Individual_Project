# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.3878s | Scout Triggers: 2 | Best Fitness: 0.820219 | Val Fitness: 0.8253257
#
# Tracing - Fold 0 Completed in 1383.7860
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.5833s | Scout Triggers: 4 | Best Fitness: 0.833698 | Val Fitness: 0.846917
#
# Tracing - Fold 1 Completed in 1209.9825
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.4894s | Scout Triggers: 2 | Best Fitness: 0.865255 | Val Fitness: 0.829226
#
# Tracing - Fold 2 Completed in 1216.8287
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.3538s | Scout Triggers: 1 | Best Fitness: 0.877179 | Val Fitness: 0.823846
#
# Tracing - Fold 3 Completed in 1194.4915
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.4159s | Scout Triggers: 1 | Best Fitness: 0.818199 | Val Fitness: 0.746129
#
# Tracing - Fold 4 Completed in 1214.3756
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_100MI_Trace.csv
