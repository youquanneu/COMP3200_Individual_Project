# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.0515s | Scout Triggers: 1 | Best Fitness: 0.800581 | Val Fitness: 0.843899
#
# Tracing - Fold 0 Completed in 189.8762
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.0605s | Scout Triggers: 2 | Best Fitness: 0.815337 | Val Fitness: 0.811780
#
# Tracing - Fold 1 Completed in 191.7261
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.0760s | Scout Triggers: 3 | Best Fitness: 0.828451 | Val Fitness: 0.825325
#
# Tracing - Fold 2 Completed in 182.0437
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.0512s | Scout Triggers: 1 | Best Fitness: 0.877160 | Val Fitness: 0.843077
#
# Tracing - Fold 3 Completed in 175.3160
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.0721s | Scout Triggers: 1 | Best Fitness: 0.791486 | Val Fitness: 0.784284
#
# Tracing - Fold 4 Completed in 173.5796
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_100MI_Trace.csv
