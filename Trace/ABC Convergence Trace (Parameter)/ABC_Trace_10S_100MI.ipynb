# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.0440s | Scout Triggers: 1 | Best Fitness: 0.806419 | Val Fitness: 0.852343
#
# Tracing - Fold 0 Completed in 133.0891
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.0474s | Scout Triggers: 3 | Best Fitness: 0.795837 | Val Fitness: 0.886766
#
# Tracing - Fold 1 Completed in 133.7612
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.0454s | Scout Triggers: 3 | Best Fitness: 0.834369 | Val Fitness: 0.807069
#
# Tracing - Fold 2 Completed in 141.9154
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.0442s | Scout Triggers: 1 | Best Fitness: 0.867918 | Val Fitness: 0.784284
#
# Tracing - Fold 3 Completed in 134.9951
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.0418s | Scout Triggers: 2 | Best Fitness: 0.786975 | Val Fitness: 0.804485
#
# Tracing - Fold 4 Completed in 132.7267
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_100MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_10SN_5TL_100MI_MCC.png
