# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.0653s | Scout Triggers: 4 | Best Fitness: 0.807748 | Val Fitness: 0.784284
#
# Tracing - Fold 0 Completed in 189.2737
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.0695s | Scout Triggers: 5 | Best Fitness: 0.805251 | Val Fitness: 0.852343
#
# Tracing - Fold 1 Completed in 190.8617
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.0587s | Scout Triggers: 1 | Best Fitness: 0.852401 | Val Fitness: 0.846917
#
# Tracing - Fold 2 Completed in 182.1989
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.0696s | Scout Triggers: 6 | Best Fitness: 0.887218 | Val Fitness: 0.823575
#
# Tracing - Fold 3 Completed in 178.1382
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.0614s | Scout Triggers: 4 | Best Fitness: 0.810112 | Val Fitness: 0.823846
#
# Tracing - Fold 4 Completed in 176.5745
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_100MI_Trace.csv
