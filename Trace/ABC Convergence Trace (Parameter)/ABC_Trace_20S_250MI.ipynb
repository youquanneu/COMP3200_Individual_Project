# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 250 complete | Duration: 0.1167s | Scout Triggers: 3 | Best Fitness: 0.839998 | Val Fitness: 0.789057
#
# Tracing - Fold 0 Completed in 928.5020
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.1575s | Scout Triggers: 4 | Best Fitness: 0.832610 | Val Fitness: 0.860555
#
# Tracing - Fold 1 Completed in 1000.4819
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.1363s | Scout Triggers: 6 | Best Fitness: 0.843630 | Val Fitness: 0.8438997
#
# Tracing - Fold 2 Completed in 914.4094
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.1165s | Scout Triggers: 2 | Best Fitness: 0.882357 | Val Fitness: 0.746129
#
# Tracing - Fold 3 Completed in 937.4251
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.1010s | Scout Triggers: 2 | Best Fitness: 0.811012 | Val Fitness: 0.789057
#
# Tracing - Fold 4 Completed in 943.8047
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_250MI_Trace.csv
