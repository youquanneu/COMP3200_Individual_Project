# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 250 complete | Duration: 0.1238s | Scout Triggers: 2 | Best Fitness: 0.840278 | Val Fitness: 0.802491
#
# Tracing - Fold 0 Completed in 873.0758
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.1014s | Scout Triggers: 1 | Best Fitness: 0.833117 | Val Fitness: 0.843899
#
# Tracing - Fold 1 Completed in 853.7331
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.0929s | Scout Triggers: 2 | Best Fitness: 0.834776 | Val Fitness: 0.804485
#
# Tracing - Fold 2 Completed in 791.6825
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.0968s | Scout Triggers: 4 | Best Fitness: 0.887264 | Val Fitness: 0.823575
#
# Tracing - Fold 3 Completed in 733.5775
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.0878s | Scout Triggers: 3 | Best Fitness: 0.829810 | Val Fitness: 0.8082439
#
# Tracing - Fold 4 Completed in 730.2354
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_250MI_Trace.csv
