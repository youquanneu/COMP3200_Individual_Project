# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 250 complete | Duration: 0.4906s | Scout Triggers: 1 | Best Fitness: 0.818824 | Val Fitness: 0.8070690
#
# Tracing - Fold 0 Completed in 3212.6518
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.3852s | Scout Triggers: 2 | Best Fitness: 0.833717 | Val Fitness: 0.829226
#
# Tracing - Fold 1 Completed in 3014.3415
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.3034s | Scout Triggers: 2 | Best Fitness: 0.850385 | Val Fitness: 0.852343
#
# Tracing - Fold 2 Completed in 2582.0235
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.2913s | Scout Triggers: 0 | Best Fitness: 0.871197 | Val Fitness: 0.808243
#
# Tracing - Fold 3 Completed in 2103.4345
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.2147s | Scout Triggers: 3 | Best Fitness: 0.818782 | Val Fitness: 0.803846
#
# Tracing - Fold 4 Completed in 2034.8638
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_250MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_20SN_10TL_250MI_MCC.png
