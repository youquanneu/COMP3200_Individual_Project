# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 250 complete | Duration: 0.0914s | Scout Triggers: 4 | Best Fitness: 0.816622 | Val Fitness: 0.886766
#
# Tracing - Fold 0 Completed in 682.3403
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.0821s | Scout Triggers: 1 | Best Fitness: 0.838212 | Val Fitness: 0.748888
#
# Tracing - Fold 1 Completed in 691.3485
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.0782s | Scout Triggers: 1 | Best Fitness: 0.843943 | Val Fitness: 0.825325
#
# Tracing - Fold 2 Completed in 630.9527
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.0742s | Scout Triggers: 1 | Best Fitness: 0.862532 | Val Fitness: 0.823846
#
# Tracing - Fold 3 Completed in 586.1020
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.0947s | Scout Triggers: 2 | Best Fitness: 0.811791 | Val Fitness: 0.746129
#
# Tracing - Fold 4 Completed in 612.5328
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_250MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_20SN_10TL_250MI_MCC.png
