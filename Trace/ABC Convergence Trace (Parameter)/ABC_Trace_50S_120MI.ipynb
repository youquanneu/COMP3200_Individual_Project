# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 50
max_iteration = 120
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 120 complete | Duration: 0.4054s | Scout Triggers: 6 | Best Fitness: 0.831174 | Val Fitness: 0.811780
#
# Tracing - Fold 0 Completed in 1435.2520
#
# Tracing - Fold 1
# Seed 160  | Iteration 120 complete | Duration: 0.4211s | Scout Triggers: 1 | Best Fitness: 0.831292 | Val Fitness: 0.904521
#
# Tracing - Fold 1 Completed in 1438.9206
#
# Tracing - Fold 2
# Seed 160  | Iteration 120 complete | Duration: 0.3803s | Scout Triggers: 2 | Best Fitness: 0.838963 | Val Fitness: 0.8070697
#
# Tracing - Fold 2 Completed in 1527.8170
#
# Tracing - Fold 3
# Seed 160  | Iteration 120 complete | Duration: 0.3614s | Scout Triggers: 4 | Best Fitness: 0.909332 | Val Fitness: 0.8630772
#
# Tracing - Fold 3 Completed in 1363.7103
#
# Tracing - Fold 4
# Seed 160  | Iteration 120 complete | Duration: 0.3974s | Scout Triggers: 6 | Best Fitness: 0.824673 | Val Fitness: 0.9045217
#
# Tracing - Fold 4 Completed in 1371.3392
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_50SN_25TL_120MI_Trace.csv
