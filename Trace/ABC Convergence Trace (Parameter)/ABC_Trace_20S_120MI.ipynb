# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 120
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 120 complete | Duration: 0.2156s | Scout Triggers: 3 | Best Fitness: 0.826942 | Val Fitness: 0.785727
#
# Tracing - Fold 0 Completed in 612.7669
#
# Tracing - Fold 1
# Seed 160  | Iteration 120 complete | Duration: 0.2065s | Scout Triggers: 5 | Best Fitness: 0.808730 | Val Fitness: 0.864923
#
# Tracing - Fold 1 Completed in 794.6392
#
# Tracing - Fold 2
# Seed 160  | Iteration 120 complete | Duration: 0.1547s | Scout Triggers: 4 | Best Fitness: 0.851876 | Val Fitness: 0.807069
#
# Tracing - Fold 2 Completed in 667.3541
#
# Tracing - Fold 3
# Seed 160  | Iteration 120 complete | Duration: 0.1395s | Scout Triggers: 5 | Best Fitness: 0.867043 | Val Fitness: 0.784284
#
# Tracing - Fold 3 Completed in 441.5093
#
# Tracing - Fold 4
# Seed 160  | Iteration 120 complete | Duration: 0.1364s | Scout Triggers: 3 | Best Fitness: 0.792041 | Val Fitness: 0.7867117
#
# Tracing - Fold 4 Completed in 447.3260
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_120MI_Trace.csv
