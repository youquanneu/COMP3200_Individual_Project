# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 80
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.7362s | Scout Triggers: 5 | Best Fitness: 0.842630 | Val Fitness: 0.7857277
#
# Tracing - Fold 0 Completed in 2698.5567
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.7793s | Scout Triggers: 6 | Best Fitness: 0.843894 | Val Fitness: 0.804485
#
# Tracing - Fold 1 Completed in 2360.4233
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.7761s | Scout Triggers: 5 | Best Fitness: 0.846154 | Val Fitness: 0.8292261
#
# Tracing - Fold 2 Completed in 2348.0784
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.8205s | Scout Triggers: 8 | Best Fitness: 0.877264 | Val Fitness: 0.7842845
#
# Tracing - Fold 3 Completed in 2371.5765
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.6984s | Scout Triggers: 3 | Best Fitness: 0.833474 | Val Fitness: 0.8038465
#
# Tracing - Fold 4 Completed in 2112.7535
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_80SN_40TL_100MI_Trace.csv
