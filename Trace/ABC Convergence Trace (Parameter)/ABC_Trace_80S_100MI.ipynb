# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 80
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 1.2194s | Scout Triggers: 3 | Best Fitness: 0.839085 | Val Fitness: 0.829226
#
# Tracing - Fold 0 Completed in 2133.9507
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.8552s | Scout Triggers: 2 | Best Fitness: 0.838447 | Val Fitness: 0.846917
#
# Tracing - Fold 1 Completed in 2810.7804
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.7406s | Scout Triggers: 1 | Best Fitness: 0.863818 | Val Fitness: 0.864923
#
# Tracing - Fold 2 Completed in 2696.5350
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.7217s | Scout Triggers: 3 | Best Fitness: 0.885131 | Val Fitness: 0.786711
#
# Tracing - Fold 3 Completed in 2920.6654
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 1.1898s | Scout Triggers: 2 | Best Fitness: 0.836244 | Val Fitness: 0.784284
#
# Tracing - Fold 4 Completed in 2945.1292
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_80SN_40TL_100MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_80SN_40TL_100MI_MCC.png
