# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 80
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Seed 160  | Iteration 150 complete | Duration: 0.3083s | Scout Triggers: 2 | Best Fitness: 0.847118 | Val Fitness: 0.807069
#
# Tracing - Fold 0 Completed in 1410.9615
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.3078s | Scout Triggers: 1 | Best Fitness: 0.841814 | Val Fitness: 0.852343
#
# Tracing - Fold 1 Completed in 1429.3159
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.3159s | Scout Triggers: 3 | Best Fitness: 0.870550 | Val Fitness: 0.846917
#
# Tracing - Fold 2 Completed in 1444.6954
#
# Tracing - Fold 3
# Seed 158  | Iteration 125 complete | Duration: 0.3379s | Scout Triggers: 2 | Best Fitness: 0.904943 | Val Fitness: 0.803846

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_80SN_40TL_150MI_MCC.png
