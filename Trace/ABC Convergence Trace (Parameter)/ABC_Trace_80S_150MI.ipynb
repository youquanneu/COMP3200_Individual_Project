# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 80
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.9189s | Scout Triggers: 3 | Best Fitness: 0.833101 | Val Fitness: 0.8469177
#
# Tracing - Fold 0 Completed in 3872.5321
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.7712s | Scout Triggers: 8 | Best Fitness: 0.855015 | Val Fitness: 0.785727
#
# Tracing - Fold 1 Completed in 3491.2904
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.7842s | Scout Triggers: 6 | Best Fitness: 0.878154 | Val Fitness: 0.829226
#
# Tracing - Fold 2 Completed in 3432.7993
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.5536s | Scout Triggers: 1 | Best Fitness: 0.893219 | Val Fitness: 0.765794
#
# Tracing - Fold 3 Completed in 2942.1280
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.5831s | Scout Triggers: 4 | Best Fitness: 0.823347 | Val Fitness: 0.784615
#
# Tracing - Fold 4 Completed in 2906.7099
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_80SN_40TL_150MI_Trace.csv
