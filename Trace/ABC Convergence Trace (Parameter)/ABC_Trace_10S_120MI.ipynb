# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 120
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 120 complete | Duration: 0.0867s | Scout Triggers: 2 | Best Fitness: 0.808834 | Val Fitness: 0.825325
#
# Tracing - Fold 0 Completed in 280.8086
#
# Tracing - Fold 1
# Seed 160  | Iteration 120 complete | Duration: 0.1593s | Scout Triggers: 3 | Best Fitness: 0.829783 | Val Fitness: 0.807069
#
# Tracing - Fold 1 Completed in 351.9480
#
# Tracing - Fold 2
# Seed 160  | Iteration 120 complete | Duration: 0.1079s | Scout Triggers: 3 | Best Fitness: 0.862058 | Val Fitness: 0.829226
#
# Tracing - Fold 2 Completed in 453.6011
#
# Tracing - Fold 3
# Seed 160  | Iteration 120 complete | Duration: 0.1154s | Scout Triggers: 4 | Best Fitness: 0.883797 | Val Fitness: 0.765072
#
# Tracing - Fold 3 Completed in 389.2290
#
# Tracing - Fold 4
# Seed 160  | Iteration 120 complete | Duration: 0.1061s | Scout Triggers: 3 | Best Fitness: 0.802381 | Val Fitness: 0.811780
#
# Tracing - Fold 4 Completed in 389.5859
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_120MI_Trace.csv
