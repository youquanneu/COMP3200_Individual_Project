# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 500
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 500 complete | Duration: 0.0508s | Scout Triggers: 2 | Best Fitness: 0.853592 | Val Fitness: 0.767220
#
# Tracing - Fold 0 Completed in 903.4817
#
# Tracing - Fold 1
# Seed 160  | Iteration 500 complete | Duration: 0.0545s | Scout Triggers: 3 | Best Fitness: 0.820347 | Val Fitness: 0.860555
#
# Tracing - Fold 1 Completed in 896.0849
#
# Tracing - Fold 2
# Seed 160  | Iteration 500 complete | Duration: 0.0538s | Scout Triggers: 4 | Best Fitness: 0.866496 | Val Fitness: 0.869394
#
# Tracing - Fold 2 Completed in 829.1241
#
# Tracing - Fold 3
# Seed 160  | Iteration 500 complete | Duration: 0.0497s | Scout Triggers: 2 | Best Fitness: 0.895121 | Val Fitness: 0.826124
#
# Tracing - Fold 3 Completed in 793.9219
#
# Tracing - Fold 4
# Seed 160  | Iteration 500 complete | Duration: 0.0563s | Scout Triggers: 5 | Best Fitness: 0.831309 | Val Fitness: 0.764615
#
# Tracing - Fold 4 Completed in 800.1259
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_500MI_Trace.csv
