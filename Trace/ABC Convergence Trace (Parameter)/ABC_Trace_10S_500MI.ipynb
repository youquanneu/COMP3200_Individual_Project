# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 500
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 500 complete | Duration: 0.0474s | Scout Triggers: 3 | Best Fitness: 0.825761 | Val Fitness: 0.825325
#
# Tracing - Fold 0 Completed in 706.6755
#
# Tracing - Fold 1
# Seed 160  | Iteration 500 complete | Duration: 0.0484s | Scout Triggers: 2 | Best Fitness: 0.807006 | Val Fitness: 0.886766
#
# Tracing - Fold 1 Completed in 701.6178
#
# Tracing - Fold 2
# Seed 160  | Iteration 500 complete | Duration: 0.0430s | Scout Triggers: 2 | Best Fitness: 0.832106 | Val Fitness: 0.807069
#
# Tracing - Fold 2 Completed in 649.6867
#
# Tracing - Fold 3
# Seed 160  | Iteration 500 complete | Duration: 0.0409s | Scout Triggers: 1 | Best Fitness: 0.877775 | Val Fitness: 0.844376
#
# Tracing - Fold 3 Completed in 620.4233
#
# Tracing - Fold 4
# Seed 160  | Iteration 500 complete | Duration: 0.0405s | Scout Triggers: 2 | Best Fitness: 0.799696 | Val Fitness: 0.784284
#
# Tracing - Fold 4 Completed in 617.0367
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_500MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_10SN_5TL_500MI_MCC.png
