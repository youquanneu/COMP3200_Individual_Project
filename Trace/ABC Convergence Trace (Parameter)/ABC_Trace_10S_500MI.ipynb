# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 500
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 500 complete | Duration: 0.0508s | Scout Triggers: 0 | Best Fitness: 0.810564 | Val Fitness: 0.807069
#
# Tracing - Fold 0 Completed in 913.8174
#
# Tracing - Fold 1
# Seed 160  | Iteration 500 complete | Duration: 0.0465s | Scout Triggers: 0 | Best Fitness: 0.830331 | Val Fitness: 0.785727
#
# Tracing - Fold 1 Completed in 775.3672
#
# Tracing - Fold 2
# Seed 160  | Iteration 500 complete | Duration: 0.0432s | Scout Triggers: 1 | Best Fitness: 0.845914 | Val Fitness: 0.735748
#
# Tracing - Fold 2 Completed in 717.6221
#
# Tracing - Fold 3
# Seed 160  | Iteration 500 complete | Duration: 0.0500s | Scout Triggers: 4 | Best Fitness: 0.864940 | Val Fitness: 0.764615
#
# Tracing - Fold 3 Completed in 697.8549
#
# Tracing - Fold 4
# Seed 160  | Iteration 500 complete | Duration: 0.0462s | Scout Triggers: 1 | Best Fitness: 0.809911 | Val Fitness: 0.706154
#
# Tracing - Fold 4 Completed in 694.9509
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_500MI_Trace.csv
