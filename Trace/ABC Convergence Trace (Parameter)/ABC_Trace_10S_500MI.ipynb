# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 500
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 500 complete | Duration: 0.1321s | Scout Triggers: 5 | Best Fitness: 0.836737 | Val Fitness: 0.767220
#
# Tracing - Fold 0 Completed in 2730.5114
#
# Tracing - Fold 1
# Seed 160  | Iteration 500 complete | Duration: 0.1102s | Scout Triggers: 2 | Best Fitness: 0.862743 | Val Fitness: 0.829226
#
# Tracing - Fold 1 Completed in 1885.6051
#
# Tracing - Fold 2
# Seed 160  | Iteration 500 complete | Duration: 0.0889s | Scout Triggers: 3 | Best Fitness: 0.859436 | Val Fitness: 0.864923
#
# Tracing - Fold 2 Completed in 1553.2322
#
# Tracing - Fold 3
# Seed 160  | Iteration 500 complete | Duration: 0.0958s | Scout Triggers: 4 | Best Fitness: 0.901245 | Val Fitness: 0.765072
#
# Tracing - Fold 3 Completed in 1393.9602
#
# Tracing - Fold 4
# Seed 160  | Iteration 500 complete | Duration: 0.0978s | Scout Triggers: 3 | Best Fitness: 0.821876 | Val Fitness: 0.823575
#
# Tracing - Fold 4 Completed in 1370.5657
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_500MI_Trace.csv
