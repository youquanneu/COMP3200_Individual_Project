# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 250 complete | Duration: 0.0389s | Scout Triggers: 0 | Best Fitness: 0.809439 | Val Fitness: 0.835549
#
# Tracing - Fold 0 Completed in 336.3474
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.0534s | Scout Triggers: 1 | Best Fitness: 0.827280 | Val Fitness: 0.852343
#
# Tracing - Fold 1 Completed in 329.8775
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.0415s | Scout Triggers: 3 | Best Fitness: 0.835922 | Val Fitness: 0.846917
#
# Tracing - Fold 2 Completed in 340.7118
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.0364s | Scout Triggers: 0 | Best Fitness: 0.867699 | Val Fitness: 0.823846
#
# Tracing - Fold 3 Completed in 302.4642
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.0359s | Scout Triggers: 0 | Best Fitness: 0.814629 | Val Fitness: 0.804485
#
# Tracing - Fold 4 Completed in 294.9822
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_250MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_10SN_5TL_250MI_MCC.png
