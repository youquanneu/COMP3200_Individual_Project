# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 250 complete | Duration: 0.1553s | Scout Triggers: 3 | Best Fitness: 0.830439 | Val Fitness: 0.789057
#
# Tracing - Fold 0 Completed in 1452.7386
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.1162s | Scout Triggers: 1 | Best Fitness: 0.822096 | Val Fitness: 0.852343
#
# Tracing - Fold 1 Completed in 1279.0683
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.1085s | Scout Triggers: 3 | Best Fitness: 0.825890 | Val Fitness: 0.876588
#
# Tracing - Fold 2 Completed in 998.4716
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.1155s | Scout Triggers: 4 | Best Fitness: 0.868257 | Val Fitness: 0.826124
#
# Tracing - Fold 3 Completed in 894.8630
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.1105s | Scout Triggers: 2 | Best Fitness: 0.809882 | Val Fitness: 0.785727
#
# Tracing - Fold 4 Completed in 853.0080
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_250MI_Trace.csv
