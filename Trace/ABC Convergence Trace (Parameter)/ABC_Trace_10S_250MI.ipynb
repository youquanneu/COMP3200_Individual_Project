# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 250 complete | Duration: 0.0510s | Scout Triggers: 1 | Best Fitness: 0.812270 | Val Fitness: 0.746129
#
# Tracing - Fold 0 Completed in 476.8000
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.0556s | Scout Triggers: 2 | Best Fitness: 0.814717 | Val Fitness: 0.777350
#
# Tracing - Fold 1 Completed in 434.5715
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.0482s | Scout Triggers: 2 | Best Fitness: 0.827568 | Val Fitness: 0.843899
#
# Tracing - Fold 2 Completed in 401.6281
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.0536s | Scout Triggers: 2 | Best Fitness: 0.871887 | Val Fitness: 0.863077
#
# Tracing - Fold 3 Completed in 371.8949
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.0444s | Scout Triggers: 1 | Best Fitness: 0.793516 | Val Fitness: 0.823575
#
# Tracing - Fold 4 Completed in 371.0553
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_250MI_Trace.csv
