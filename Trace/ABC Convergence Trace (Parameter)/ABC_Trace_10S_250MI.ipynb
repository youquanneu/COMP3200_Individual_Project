# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 250 complete | Duration: 0.0603s | Scout Triggers: 4 | Best Fitness: 0.840167 | Val Fitness: 0.807069
#
# Tracing - Fold 0 Completed in 470.8786
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.0566s | Scout Triggers: 5 | Best Fitness: 0.842575 | Val Fitness: 0.864923
#
# Tracing - Fold 1 Completed in 433.2881
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.0601s | Scout Triggers: 1 | Best Fitness: 0.864539 | Val Fitness: 0.825325
#
# Tracing - Fold 2 Completed in 458.5167
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.0623s | Scout Triggers: 4 | Best Fitness: 0.890729 | Val Fitness: 0.847841
#
# Tracing - Fold 3 Completed in 436.2882
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.0592s | Scout Triggers: 3 | Best Fitness: 0.812869 | Val Fitness: 0.725659
#
# Tracing - Fold 4 Completed in 433.9481
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_250MI_Trace.csv
