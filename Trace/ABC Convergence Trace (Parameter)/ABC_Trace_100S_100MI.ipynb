# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 100
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.6235s | Scout Triggers: 4 | Best Fitness: 0.828689 | Val Fitness: 0.8469173
#
# Tracing - Fold 0 Completed in 1701.3311
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.5915s | Scout Triggers: 7 | Best Fitness: 0.844210 | Val Fitness: 0.8469174
#
# Tracing - Fold 1 Completed in 1682.6939
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.6152s | Scout Triggers: 5 | Best Fitness: 0.859661 | Val Fitness: 0.8253256
#
# Tracing - Fold 2 Completed in 1628.6313
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.4869s | Scout Triggers: 2 | Best Fitness: 0.886219 | Val Fitness: 0.823846
#
# Tracing - Fold 3 Completed in 1637.3331
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.5925s | Scout Triggers: 7 | Best Fitness: 0.827412 | Val Fitness: 0.8438992
#
# Tracing - Fold 4 Completed in 1645.6480
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_100SN_50TL_100MI_Trace.csv
