# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 100
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.4947s | Scout Triggers: 3 | Best Fitness: 0.839725 | Val Fitness: 0.835549
#
# Tracing - Fold 0 Completed in 1562.9138
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.4766s | Scout Triggers: 7 | Best Fitness: 0.850581 | Val Fitness: 0.829226
#
# Tracing - Fold 1 Completed in 1434.5654
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.4302s | Scout Triggers: 1 | Best Fitness: 0.852980 | Val Fitness: 0.8438991
#
# Tracing - Fold 2 Completed in 1343.1938
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.4744s | Scout Triggers: 1 | Best Fitness: 0.880456 | Val Fitness: 0.8235753
#
# Tracing - Fold 3 Completed in 1332.0433
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.4064s | Scout Triggers: 4 | Best Fitness: 0.842065 | Val Fitness: 0.804485
#
# Tracing - Fold 4 Completed in 1364.4442
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_100SN_50TL_100MI_Trace.csv
