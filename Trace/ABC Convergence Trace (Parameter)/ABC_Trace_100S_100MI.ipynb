# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 100
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.4205s | Scout Triggers: 1 | Best Fitness: 0.837228 | Val Fitness: 0.829226
#
# Tracing - Fold 0 Completed in 1269.3003
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.4444s | Scout Triggers: 3 | Best Fitness: 0.858725 | Val Fitness: 0.807069
#
# Tracing - Fold 1 Completed in 1291.1847
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.4163s | Scout Triggers: 0 | Best Fitness: 0.864747 | Val Fitness: 0.823575
#
# Tracing - Fold 2 Completed in 1287.2408
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.4049s | Scout Triggers: 0 | Best Fitness: 0.885650 | Val Fitness: 0.765072
#
# Tracing - Fold 3 Completed in 1266.8587
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.4127s | Scout Triggers: 1 | Best Fitness: 0.833442 | Val Fitness: 0.823575
#
# Tracing - Fold 4 Completed in 1259.8442
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_100SN_50TL_100MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_100SN_50TL_100MI_MCC.png
