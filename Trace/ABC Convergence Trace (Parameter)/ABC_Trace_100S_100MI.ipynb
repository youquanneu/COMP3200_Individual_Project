# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 100
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 1.1618s | Scout Triggers: 1 | Best Fitness: 0.837228 | Val Fitness: 0.829226
#
# Tracing - Fold 0 Completed in 2855.6008
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.9224s | Scout Triggers: 3 | Best Fitness: 0.858725 | Val Fitness: 0.807069
#
# Tracing - Fold 1 Completed in 3499.3256
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 1.0903s | Scout Triggers: 0 | Best Fitness: 0.864747 | Val Fitness: 0.823575
#
# Tracing - Fold 2 Completed in 3569.0565
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 2.2087s | Scout Triggers: 0 | Best Fitness: 0.885650 | Val Fitness: 0.765072
#
# Tracing - Fold 3 Completed in 3711.5488
#
# Tracing - Fold 4
# Seed 138  | Iteration 010 complete | Duration: 1.2013s | Scout Triggers: 0 | Best Fitness: 0.797645 | Val Fitness: 0.784615

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Plotting.plot_rigorous_convergence(trace_result,
#       2                                    experiment_name  = expr_name,
#       3                                    is_final_record  = True)
#
# NameError: name 'Plotting' is not defined
