# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 100
max_iteration = 120
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 120 complete | Duration: 0.4695s | Scout Triggers: 3 | Best Fitness: 0.841264 | Val Fitness: 0.8649231
#
# Tracing - Fold 0 Completed in 1845.7788
#
# Tracing - Fold 1
# Seed 160  | Iteration 120 complete | Duration: 0.4260s | Scout Triggers: 0 | Best Fitness: 0.858536 | Val Fitness: 0.789057
#
# Tracing - Fold 1 Completed in 1697.7371
#
# Tracing - Fold 2
# Seed 160  | Iteration 120 complete | Duration: 0.4453s | Scout Triggers: 4 | Best Fitness: 0.877035 | Val Fitness: 0.8253256
#
# Tracing - Fold 2 Completed in 1601.1894
#
# Tracing - Fold 3
# Seed 160  | Iteration 120 complete | Duration: 0.4286s | Scout Triggers: 1 | Best Fitness: 0.883502 | Val Fitness: 0.765794
#
# Tracing - Fold 3 Completed in 1621.5555
#
# Tracing - Fold 4
# Seed 160  | Iteration 120 complete | Duration: 0.4036s | Scout Triggers: 4 | Best Fitness: 0.844245 | Val Fitness: 0.8235755
#
# Tracing - Fold 4 Completed in 1463.7105
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_100SN_50TL_120MI_Trace.csv
