# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 100
max_iteration = 120
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 120 complete | Duration: 0.4107s | Scout Triggers: 5 | Best Fitness: 0.835989 | Val Fitness: 0.784284
#
# Tracing - Fold 0 Completed in 1530.6212
#
# Tracing - Fold 1
# Seed 160  | Iteration 120 complete | Duration: 0.4440s | Scout Triggers: 1 | Best Fitness: 0.867467 | Val Fitness: 0.846917
#
# Tracing - Fold 1 Completed in 1555.1585
#
# Tracing - Fold 2
# Seed 160  | Iteration 120 complete | Duration: 0.4318s | Scout Triggers: 4 | Best Fitness: 0.865094 | Val Fitness: 0.852343
#
# Tracing - Fold 2 Completed in 1529.2441
#
# Tracing - Fold 3
# Seed 160  | Iteration 120 complete | Duration: 0.4113s | Scout Triggers: 5 | Best Fitness: 0.896943 | Val Fitness: 0.764615
#
# Tracing - Fold 3 Completed in 1517.6952
#
# Tracing - Fold 4
# Seed 160  | Iteration 120 complete | Duration: 0.3870s | Scout Triggers: 1 | Best Fitness: 0.847068 | Val Fitness: 0.725385
#
# Tracing - Fold 4 Completed in 1428.0960
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_100SN_50TL_120MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_100SN_50TL_120MI_MCC.png
