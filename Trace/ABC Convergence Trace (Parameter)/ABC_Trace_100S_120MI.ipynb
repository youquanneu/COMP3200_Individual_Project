# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 100
max_iteration = 120
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 120 complete | Duration: 0.6560s | Scout Triggers: 6 | Best Fitness: 0.840596 | Val Fitness: 0.7453859
#
# Tracing - Fold 0 Completed in 1909.4608
#
# Tracing - Fold 1
# Seed 160  | Iteration 120 complete | Duration: 0.5170s | Scout Triggers: 6 | Best Fitness: 0.852870 | Val Fitness: 0.8070699
#
# Tracing - Fold 1 Completed in 1861.0747
#
# Tracing - Fold 2
# Seed 160  | Iteration 120 complete | Duration: 0.6093s | Scout Triggers: 1 | Best Fitness: 0.850182 | Val Fitness: 0.852343
#
# Tracing - Fold 2 Completed in 1813.8832
#
# Tracing - Fold 3
# Seed 160  | Iteration 120 complete | Duration: 0.5620s | Scout Triggers: 4 | Best Fitness: 0.895133 | Val Fitness: 0.8050856
#
# Tracing - Fold 3 Completed in 1773.8384
#
# Tracing - Fold 4
# Seed 160  | Iteration 120 complete | Duration: 0.5649s | Scout Triggers: 3 | Best Fitness: 0.821300 | Val Fitness: 0.744993
#
# Tracing - Fold 4 Completed in 1665.1757
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_100SN_50TL_120MI_Trace.csv
