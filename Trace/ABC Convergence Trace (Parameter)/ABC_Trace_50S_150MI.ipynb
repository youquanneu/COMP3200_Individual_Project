# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 50
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.9401s | Scout Triggers: 1 | Best Fitness: 0.829647 | Val Fitness: 0.8355494
#
# Tracing - Fold 0 Completed in 4636.6777
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.7787s | Scout Triggers: 1 | Best Fitness: 0.839546 | Val Fitness: 0.818953
#
# Tracing - Fold 1 Completed in 4011.5887
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.6949s | Scout Triggers: 1 | Best Fitness: 0.856519 | Val Fitness: 0.789057
#
# Tracing - Fold 2 Completed in 3090.1156
#
# Tracing - Fold 3
# Seed 146  | Iteration 055 complete | Duration: 0.4410s | Scout Triggers: 1 | Best Fitness: 0.888060 | Val Fitness: 0.844376

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
