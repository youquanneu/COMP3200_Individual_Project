# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 50
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Seed 160  | Iteration 150 complete | Duration: 0.1842s | Scout Triggers: 1 | Best Fitness: 0.841283 | Val Fitness: 0.802491
#
# Tracing - Fold 0 Completed in 850.2282
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.1932s | Scout Triggers: 3 | Best Fitness: 0.838859 | Val Fitness: 0.811780
#
# Tracing - Fold 1 Completed in 847.9018
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.1808s | Scout Triggers: 0 | Best Fitness: 0.857719 | Val Fitness: 0.804485
#
# Tracing - Fold 2 Completed in 849.3841
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.1761s | Scout Triggers: 1 | Best Fitness: 0.886088 | Val Fitness: 0.784284
#
# Tracing - Fold 3 Completed in 826.9884
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.1811s | Scout Triggers: 2 | Best Fitness: 0.829475 | Val Fitness: 0.864923
#
# Tracing - Fold 4 Completed in 816.0079
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_50SN_25TL_150MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_50SN_25TL_150MI_MCC.png
