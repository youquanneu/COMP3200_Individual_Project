# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 50
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.3144s | Scout Triggers: 1 | Best Fitness: 0.830768 | Val Fitness: 0.7256598
#
# Tracing - Fold 0 Completed in 1396.0827
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.2648s | Scout Triggers: 5 | Best Fitness: 0.843372 | Val Fitness: 0.8117806
#
# Tracing - Fold 1 Completed in 1383.1047
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.3151s | Scout Triggers: 7 | Best Fitness: 0.857987 | Val Fitness: 0.7488883
#
# Tracing - Fold 2 Completed in 1388.2976
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.2104s | Scout Triggers: 10 | Best Fitness: 0.882427 | Val Fitness: 0.823575
#
# Tracing - Fold 3 Completed in 1026.5733
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.1974s | Scout Triggers: 2 | Best Fitness: 0.833932 | Val Fitness: 0.844376
#
# Tracing - Fold 4 Completed in 875.5383
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_50SN_25TL_150MI_Trace.csv
