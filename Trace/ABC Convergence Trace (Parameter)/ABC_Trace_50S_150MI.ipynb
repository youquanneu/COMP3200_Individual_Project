# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 50
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.2803s | Scout Triggers: 3 | Best Fitness: 0.841994 | Val Fitness: 0.8469179
#
# Tracing - Fold 0 Completed in 1243.4353
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.2446s | Scout Triggers: 5 | Best Fitness: 0.855506 | Val Fitness: 0.886766
#
# Tracing - Fold 1 Completed in 1165.2882
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.2159s | Scout Triggers: 1 | Best Fitness: 0.858118 | Val Fitness: 0.7857276
#
# Tracing - Fold 2 Completed in 1052.9352
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.2018s | Scout Triggers: 1 | Best Fitness: 0.894060 | Val Fitness: 0.8261245
#
# Tracing - Fold 3 Completed in 977.4992
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.1913s | Scout Triggers: 1 | Best Fitness: 0.831265 | Val Fitness: 0.8238465
#
# Tracing - Fold 4 Completed in 902.0655
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_50SN_25TL_150MI_Trace.csv
