# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 100
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 250 complete | Duration: 0.5054s | Scout Triggers: 3 | Best Fitness: 0.844958 | Val Fitness: 0.8628661
#
# Tracing - Fold 0 Completed in 4194.5906
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.5039s | Scout Triggers: 7 | Best Fitness: 0.853869 | Val Fitness: 0.7712163
#
# Tracing - Fold 1 Completed in 4095.1631
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.5089s | Scout Triggers: 3 | Best Fitness: 0.876092 | Val Fitness: 0.8693944
#
# Tracing - Fold 2 Completed in 3604.2179
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.3747s | Scout Triggers: 4 | Best Fitness: 0.896519 | Val Fitness: 0.8238461
#
# Tracing - Fold 3 Completed in 2783.3970
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.3655s | Scout Triggers: 3 | Best Fitness: 0.837285 | Val Fitness: 0.7646154
#
# Tracing - Fold 4 Completed in 2744.9398
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_100SN_50TL_250MI_Trace.csv
