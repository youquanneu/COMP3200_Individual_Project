# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 100
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 250 complete | Duration: 0.3938s | Scout Triggers: 2 | Best Fitness: 0.862244 | Val Fitness: 0.748888
#
# Tracing - Fold 0 Completed in 2969.9315
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.3908s | Scout Triggers: 2 | Best Fitness: 0.864793 | Val Fitness: 0.825325
#
# Tracing - Fold 1 Completed in 3099.3413
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.3656s | Scout Triggers: 0 | Best Fitness: 0.887989 | Val Fitness: 0.835549
#
# Tracing - Fold 2 Completed in 2918.4661
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.3717s | Scout Triggers: 2 | Best Fitness: 0.899527 | Val Fitness: 0.823846
#
# Tracing - Fold 3 Completed in 3010.9212
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.3652s | Scout Triggers: 1 | Best Fitness: 0.845669 | Val Fitness: 0.825325
#
# Tracing - Fold 4 Completed in 2740.3328
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_100SN_50TL_250MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_100SN_50TL_250MI_MCC.png
