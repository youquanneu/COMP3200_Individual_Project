# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.1425s | Scout Triggers: 2 | Best Fitness: 0.839702 | Val Fitness: 0.829226
#
# Tracing - Fold 0 Completed in 569.6913
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.1314s | Scout Triggers: 5 | Best Fitness: 0.832215 | Val Fitness: 0.807069
#
# Tracing - Fold 1 Completed in 543.1445
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.1591s | Scout Triggers: 1 | Best Fitness: 0.853043 | Val Fitness: 0.789057
#
# Tracing - Fold 2 Completed in 615.1830
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.1443s | Scout Triggers: 5 | Best Fitness: 0.883680 | Val Fitness: 0.843077
#
# Tracing - Fold 3 Completed in 589.5187
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.1337s | Scout Triggers: 2 | Best Fitness: 0.828977 | Val Fitness: 0.843899
#
# Tracing - Fold 4 Completed in 538.9154
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_150MI_Trace.csv
