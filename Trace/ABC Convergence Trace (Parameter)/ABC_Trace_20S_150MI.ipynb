# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.1093s | Scout Triggers: 5 | Best Fitness: 0.838703 | Val Fitness: 0.829226
#
# Tracing - Fold 0 Completed in 516.2303
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.1085s | Scout Triggers: 2 | Best Fitness: 0.845443 | Val Fitness: 0.844757
#
# Tracing - Fold 1 Completed in 525.8229
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.1251s | Scout Triggers: 3 | Best Fitness: 0.858118 | Val Fitness: 0.789057
#
# Tracing - Fold 2 Completed in 509.3903
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.1097s | Scout Triggers: 3 | Best Fitness: 0.888875 | Val Fitness: 0.803846
#
# Tracing - Fold 3 Completed in 484.9101
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.0959s | Scout Triggers: 0 | Best Fitness: 0.816295 | Val Fitness: 0.725659
#
# Tracing - Fold 4 Completed in 474.8505
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_150MI_Trace.csv
