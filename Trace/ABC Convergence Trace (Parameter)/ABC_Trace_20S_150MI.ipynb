# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.4815s | Scout Triggers: 2 | Best Fitness: 0.818309 | Val Fitness: 0.8469179
#
# Tracing - Fold 0 Completed in 2018.7314
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.5062s | Scout Triggers: 2 | Best Fitness: 0.827983 | Val Fitness: 0.794511
#
# Tracing - Fold 1 Completed in 1815.2812
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.4349s | Scout Triggers: 1 | Best Fitness: 0.831574 | Val Fitness: 0.811780
#
# Tracing - Fold 2 Completed in 1801.9707
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.2890s | Scout Triggers: 0 | Best Fitness: 0.862832 | Val Fitness: 0.803846
#
# Tracing - Fold 3 Completed in 1628.3106
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.3666s | Scout Triggers: 2 | Best Fitness: 0.811224 | Val Fitness: 0.785727
#
# Tracing - Fold 4 Completed in 1543.8763
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_150MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_20SN_10TL_150MI_MCC.png
