# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Seed 160  | Iteration 150 complete | Duration: 0.1012s | Scout Triggers: 2 | Best Fitness: 0.815788 | Val Fitness: 0.785727
#
# Tracing - Fold 0 Completed in 404.7606
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.0891s | Scout Triggers: 2 | Best Fitness: 0.815127 | Val Fitness: 0.829226
#
# Tracing - Fold 1 Completed in 401.9267
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.1021s | Scout Triggers: 2 | Best Fitness: 0.863197 | Val Fitness: 0.748888
#
# Tracing - Fold 2 Completed in 402.8639
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.0869s | Scout Triggers: 2 | Best Fitness: 0.875542 | Val Fitness: 0.765794
#
# Tracing - Fold 3 Completed in 384.6181
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.0798s | Scout Triggers: 1 | Best Fitness: 0.812151 | Val Fitness: 0.823575
#
# Tracing - Fold 4 Completed in 372.5525
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_150MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_20SN_10TL_150MI_MCC.png
