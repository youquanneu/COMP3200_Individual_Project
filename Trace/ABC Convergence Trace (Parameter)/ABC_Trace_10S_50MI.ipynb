# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 50
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 050 complete | Duration: 0.1165s | Scout Triggers: 0 | Best Fitness: 0.793476 | Val Fitness: 0.807069
#
# Tracing - Fold 0 Completed in 101.0384
#
# Tracing - Fold 1
# Seed 160  | Iteration 050 complete | Duration: 0.1721s | Scout Triggers: 2 | Best Fitness: 0.789483 | Val Fitness: 0.807069
#
# Tracing - Fold 1 Completed in 275.2812
#
# Tracing - Fold 2
# Seed 160  | Iteration 050 complete | Duration: 0.2261s | Scout Triggers: 6 | Best Fitness: 0.808754 | Val Fitness: 0.829226
#
# Tracing - Fold 2 Completed in 284.6983
#
# Tracing - Fold 3
# Seed 160  | Iteration 050 complete | Duration: 0.2729s | Scout Triggers: 2 | Best Fitness: 0.854956 | Val Fitness: 0.804485
#
# Tracing - Fold 3 Completed in 303.4245
#
# Tracing - Fold 4
# Seed 160  | Iteration 050 complete | Duration: 0.1894s | Scout Triggers: 5 | Best Fitness: 0.806390 | Val Fitness: 0.785727
#
# Tracing - Fold 4 Completed in 316.1511
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_50MI_Trace.csv
