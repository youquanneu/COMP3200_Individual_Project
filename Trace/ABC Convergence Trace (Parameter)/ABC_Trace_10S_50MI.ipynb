# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 50
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 050 complete | Duration: 0.0838s | Scout Triggers: 4 | Best Fitness: 0.808067 | Val Fitness: 0.777350
#
# Tracing - Fold 0 Completed in 93.5303
#
# Tracing - Fold 1
# Seed 160  | Iteration 050 complete | Duration: 0.0688s | Scout Triggers: 5 | Best Fitness: 0.804434 | Val Fitness: 0.829226
#
# Tracing - Fold 1 Completed in 95.3751
#
# Tracing - Fold 2
# Seed 160  | Iteration 050 complete | Duration: 0.0626s | Scout Triggers: 5 | Best Fitness: 0.826337 | Val Fitness: 0.825325
#
# Tracing - Fold 2 Completed in 94.5606
#
# Tracing - Fold 3
# Seed 160  | Iteration 050 complete | Duration: 0.0545s | Scout Triggers: 2 | Best Fitness: 0.848508 | Val Fitness: 0.823575
#
# Tracing - Fold 3 Completed in 95.2716
#
# Tracing - Fold 4
# Seed 160  | Iteration 050 complete | Duration: 0.0793s | Scout Triggers: 5 | Best Fitness: 0.767935 | Val Fitness: 0.862866
#
# Tracing - Fold 4 Completed in 95.1356
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_50MI_Trace.csv
