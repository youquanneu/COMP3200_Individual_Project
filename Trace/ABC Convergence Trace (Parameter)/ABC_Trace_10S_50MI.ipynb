# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 50
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 050 complete | Duration: 0.0523s | Scout Triggers: 3 | Best Fitness: 0.790640 | Val Fitness: 0.823846
#
# Tracing - Fold 0 Completed in 67.6534
#
# Tracing - Fold 1
# Seed 160  | Iteration 050 complete | Duration: 0.0438s | Scout Triggers: 3 | Best Fitness: 0.819666 | Val Fitness: 0.818953
#
# Tracing - Fold 1 Completed in 67.9817
#
# Tracing - Fold 2
# Seed 160  | Iteration 050 complete | Duration: 0.0518s | Scout Triggers: 2 | Best Fitness: 0.812419 | Val Fitness: 0.864923
#
# Tracing - Fold 2 Completed in 66.8427
#
# Tracing - Fold 3
# Seed 160  | Iteration 050 complete | Duration: 0.0449s | Scout Triggers: 2 | Best Fitness: 0.843594 | Val Fitness: 0.764615
#
# Tracing - Fold 3 Completed in 67.1645
#
# Tracing - Fold 4
# Seed 160  | Iteration 050 complete | Duration: 0.0412s | Scout Triggers: 1 | Best Fitness: 0.784953 | Val Fitness: 0.807069
#
# Tracing - Fold 4 Completed in 71.4514
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_50MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_10SN_5TL_50MI_MCC.png
