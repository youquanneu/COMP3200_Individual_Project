# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 50
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 050 complete | Duration: 0.0556s | Scout Triggers: 2 | Best Fitness: 0.798748 | Val Fitness: 0.789057
#
# Tracing - Fold 0 Completed in 94.9245
#
# Tracing - Fold 1
# Seed 160  | Iteration 050 complete | Duration: 0.0661s | Scout Triggers: 0 | Best Fitness: 0.802380 | Val Fitness: 0.818953
#
# Tracing - Fold 1 Completed in 95.0080
#
# Tracing - Fold 2
# Seed 160  | Iteration 050 complete | Duration: 0.0647s | Scout Triggers: 2 | Best Fitness: 0.819661 | Val Fitness: 0.825325
#
# Tracing - Fold 2 Completed in 95.1461
#
# Tracing - Fold 3
# Seed 160  | Iteration 050 complete | Duration: 0.0569s | Scout Triggers: 4 | Best Fitness: 0.854432 | Val Fitness: 0.765794
#
# Tracing - Fold 3 Completed in 96.4548
#
# Tracing - Fold 4
# Seed 160  | Iteration 050 complete | Duration: 0.0689s | Scout Triggers: 2 | Best Fitness: 0.784186 | Val Fitness: 0.803846
#
# Tracing - Fold 4 Completed in 95.5326
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_50MI_Trace.csv
