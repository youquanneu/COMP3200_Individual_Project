# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 1000
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 1000 complete | Duration: 0.0526s | Scout Triggers: 1 | Best Fitness: 0.822021 | Val Fitness: 0.835549
#
# Tracing - Fold 0 Completed in 1684.4041
#
# Tracing - Fold 1
# Seed 160  | Iteration 1000 complete | Duration: 0.0494s | Scout Triggers: 2 | Best Fitness: 0.820695 | Val Fitness: 0.904521
#
# Tracing - Fold 1 Completed in 1410.5715
#
# Tracing - Fold 2
# Seed 160  | Iteration 1000 complete | Duration: 0.0391s | Scout Triggers: 0 | Best Fitness: 0.846778 | Val Fitness: 0.769707
#
# Tracing - Fold 2 Completed in 1341.7145
#
# Tracing - Fold 3
# Seed 160  | Iteration 1000 complete | Duration: 0.0391s | Scout Triggers: 0 | Best Fitness: 0.876481 | Val Fitness: 0.803846
#
# Tracing - Fold 3 Completed in 1310.3302
#
# Tracing - Fold 4
# Seed 160  | Iteration 1000 complete | Duration: 0.0424s | Scout Triggers: 1 | Best Fitness: 0.806355 | Val Fitness: 0.807069
#
# Tracing - Fold 4 Completed in 1292.8604
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_1000MI_Trace.csv
