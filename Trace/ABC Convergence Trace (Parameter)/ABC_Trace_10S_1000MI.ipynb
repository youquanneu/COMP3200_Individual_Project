# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 1000
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 1000 complete | Duration: 0.0544s | Scout Triggers: 2 | Best Fitness: 0.843685 | Val Fitness: 0.767220
#
# Tracing - Fold 0 Completed in 1784.4858
#
# Tracing - Fold 1
# Seed 160  | Iteration 1000 complete | Duration: 0.0710s | Scout Triggers: 2 | Best Fitness: 0.829954 | Val Fitness: 0.852343
#
# Tracing - Fold 1 Completed in 1613.6150
#
# Tracing - Fold 2
# Seed 160  | Iteration 1000 complete | Duration: 0.0458s | Scout Triggers: 2 | Best Fitness: 0.881469 | Val Fitness: 0.863077
#
# Tracing - Fold 2 Completed in 1532.7423
#
# Tracing - Fold 3
# Seed 160  | Iteration 1000 complete | Duration: 0.0496s | Scout Triggers: 3 | Best Fitness: 0.891407 | Val Fitness: 0.808243
#
# Tracing - Fold 3 Completed in 1465.8186
#
# Tracing - Fold 4
# Seed 160  | Iteration 1000 complete | Duration: 0.0591s | Scout Triggers: 3 | Best Fitness: 0.833001 | Val Fitness: 0.843899
#
# Tracing - Fold 4 Completed in 1495.8531
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_1000MI_Trace.csv
