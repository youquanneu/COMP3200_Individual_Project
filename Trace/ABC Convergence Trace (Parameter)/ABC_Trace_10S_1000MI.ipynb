# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 1000
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Seed 160  | Iteration 1000 complete | Duration: 0.0448s | Scout Triggers: 1 | Best Fitness: 0.820384 | Val Fitness: 0.771216
#
# Tracing - Fold 0 Completed in 1425.4851
#
# Tracing - Fold 1
# Seed 160  | Iteration 1000 complete | Duration: 0.0410s | Scout Triggers: 2 | Best Fitness: 0.843430 | Val Fitness: 0.811780
#
# Tracing - Fold 1 Completed in 1282.9338
#
# Tracing - Fold 2
# Seed 160  | Iteration 1000 complete | Duration: 0.0439s | Scout Triggers: 4 | Best Fitness: 0.847881 | Val Fitness: 0.829226
#
# Tracing - Fold 2 Completed in 1221.7464
#
# Tracing - Fold 3
# Seed 160  | Iteration 1000 complete | Duration: 0.0459s | Scout Triggers: 2 | Best Fitness: 0.864535 | Val Fitness: 0.863077
#
# Tracing - Fold 3 Completed in 1261.1243
#
# Tracing - Fold 4
# Seed 160  | Iteration 1000 complete | Duration: 0.0541s | Scout Triggers: 5 | Best Fitness: 0.811460 | Val Fitness: 0.764615
#
# Tracing - Fold 4 Completed in 1386.3598
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_1000MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_10SN_5TL_1000MI_MCC.png
