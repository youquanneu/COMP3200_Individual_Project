# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 80
max_iteration = 120
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 120 complete | Duration: 0.5816s | Scout Triggers: 1 | Best Fitness: 0.835228 | Val Fitness: 0.883312
#
# Tracing - Fold 0 Completed in 1963.4488
#
# Tracing - Fold 1
# Seed 160  | Iteration 120 complete | Duration: 0.5896s | Scout Triggers: 2 | Best Fitness: 0.840236 | Val Fitness: 0.8523433
#
# Tracing - Fold 1 Completed in 2151.5344
#
# Tracing - Fold 2
# Seed 160  | Iteration 120 complete | Duration: 0.7773s | Scout Triggers: 6 | Best Fitness: 0.857387 | Val Fitness: 0.8523439
#
# Tracing - Fold 2 Completed in 2193.1407
#
# Tracing - Fold 3
# Seed 160  | Iteration 120 complete | Duration: 0.5707s | Scout Triggers: 1 | Best Fitness: 0.888801 | Val Fitness: 0.7449931
#
# Tracing - Fold 3 Completed in 2196.8466
#
# Tracing - Fold 4
# Seed 160  | Iteration 120 complete | Duration: 0.6276s | Scout Triggers: 8 | Best Fitness: 0.833776 | Val Fitness: 0.744993
#
# Tracing - Fold 4 Completed in 2172.5136
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_80SN_40TL_120MI_Trace.csv
