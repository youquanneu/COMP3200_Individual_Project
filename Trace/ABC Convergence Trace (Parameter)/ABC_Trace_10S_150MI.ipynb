# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.0419s | Scout Triggers: 1 | Best Fitness: 0.810293 | Val Fitness: 0.706531
#
# Tracing - Fold 0 Completed in 201.0612
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.0438s | Scout Triggers: 1 | Best Fitness: 0.828615 | Val Fitness: 0.794511
#
# Tracing - Fold 1 Completed in 198.4323
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.0474s | Scout Triggers: 2 | Best Fitness: 0.842065 | Val Fitness: 0.767220
#
# Tracing - Fold 2 Completed in 198.2156
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.0463s | Scout Triggers: 3 | Best Fitness: 0.843937 | Val Fitness: 0.805085
#
# Tracing - Fold 3 Completed in 198.5992
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.0462s | Scout Triggers: 3 | Best Fitness: 0.802421 | Val Fitness: 0.785727
#
# Tracing - Fold 4 Completed in 199.0972
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_150MI_Trace.csv
