# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.1894s | Scout Triggers: 2 | Best Fitness: 0.816724 | Val Fitness: 0.785727
#
# Tracing - Fold 0 Completed in 841.7068
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.1719s | Scout Triggers: 4 | Best Fitness: 0.810213 | Val Fitness: 0.869394
#
# Tracing - Fold 1 Completed in 856.7571
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.2006s | Scout Triggers: 6 | Best Fitness: 0.830236 | Val Fitness: 0.811780
#
# Tracing - Fold 2 Completed in 781.3016
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.1282s | Scout Triggers: 3 | Best Fitness: 0.859985 | Val Fitness: 0.756105
#
# Tracing - Fold 3 Completed in 649.2025
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.1344s | Scout Triggers: 3 | Best Fitness: 0.789912 | Val Fitness: 0.764615
#
# Tracing - Fold 4 Completed in 603.3431
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_150MI_Trace.csv
