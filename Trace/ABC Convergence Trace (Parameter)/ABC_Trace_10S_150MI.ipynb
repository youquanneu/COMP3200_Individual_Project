# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.0456s | Scout Triggers: 1 | Best Fitness: 0.810058 | Val Fitness: 0.785727
#
# Tracing - Fold 0 Completed in 202.9712
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.0433s | Scout Triggers: 2 | Best Fitness: 0.802150 | Val Fitness: 0.748888
#
# Tracing - Fold 1 Completed in 204.3290
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.0406s | Scout Triggers: 1 | Best Fitness: 0.831927 | Val Fitness: 0.765072
#
# Tracing - Fold 2 Completed in 201.0184
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.0464s | Scout Triggers: 4 | Best Fitness: 0.858654 | Val Fitness: 0.784615
#
# Tracing - Fold 3 Completed in 209.8836
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.0410s | Scout Triggers: 1 | Best Fitness: 0.797893 | Val Fitness: 0.843077
#
# Tracing - Fold 4 Completed in 200.5890
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_150MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_10SN_5TL_150MI_MCC.png
