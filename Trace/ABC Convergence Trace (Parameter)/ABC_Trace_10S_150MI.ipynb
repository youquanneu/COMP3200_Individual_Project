# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.0747s | Scout Triggers: 2 | Best Fitness: 0.857406 | Val Fitness: 0.748888
#
# Tracing - Fold 0 Completed in 282.5825
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.0620s | Scout Triggers: 6 | Best Fitness: 0.811648 | Val Fitness: 0.825325
#
# Tracing - Fold 1 Completed in 276.8944
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.0550s | Scout Triggers: 3 | Best Fitness: 0.828471 | Val Fitness: 0.802491
#
# Tracing - Fold 2 Completed in 265.1878
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.0612s | Scout Triggers: 4 | Best Fitness: 0.866306 | Val Fitness: 0.687523
#
# Tracing - Fold 3 Completed in 253.1255
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.0667s | Scout Triggers: 2 | Best Fitness: 0.829183 | Val Fitness: 0.863077
#
# Tracing - Fold 4 Completed in 290.0384
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_150MI_Trace.csv
