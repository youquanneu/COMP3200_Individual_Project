# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 100
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.5605s | Scout Triggers: 4 | Best Fitness: 0.853394 | Val Fitness: 0.8253256
#
# Tracing - Fold 0 Completed in 2565.1479
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.5422s | Scout Triggers: 1 | Best Fitness: 0.848257 | Val Fitness: 0.8253255
#
# Tracing - Fold 1 Completed in 2462.0767
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.5252s | Scout Triggers: 4 | Best Fitness: 0.857678 | Val Fitness: 0.8070696
#
# Tracing - Fold 2 Completed in 2469.3223
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.4135s | Scout Triggers: 3 | Best Fitness: 0.892733 | Val Fitness: 0.7449936
#
# Tracing - Fold 3 Completed in 2333.0672
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.4652s | Scout Triggers: 5 | Best Fitness: 0.836099 | Val Fitness: 0.8235754
#
# Tracing - Fold 4 Completed in 2140.8686
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_100SN_50TL_150MI_Trace.csv
