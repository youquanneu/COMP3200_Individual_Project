# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 100
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.4149s | Scout Triggers: 2 | Best Fitness: 0.854532 | Val Fitness: 0.886766
#
# Tracing - Fold 0 Completed in 1903.3541
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.4018s | Scout Triggers: 1 | Best Fitness: 0.864830 | Val Fitness: 0.789057
#
# Tracing - Fold 1 Completed in 1941.9590
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.4271s | Scout Triggers: 3 | Best Fitness: 0.879477 | Val Fitness: 0.789057
#
# Tracing - Fold 2 Completed in 1900.5296
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.3953s | Scout Triggers: 3 | Best Fitness: 0.885484 | Val Fitness: 0.744993
#
# Tracing - Fold 3 Completed in 1822.4045
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.3571s | Scout Triggers: 3 | Best Fitness: 0.846717 | Val Fitness: 0.862866
#
# Tracing - Fold 4 Completed in 1639.9443
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_100SN_50TL_150MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_100SN_50TL_150MI_MCC.png
