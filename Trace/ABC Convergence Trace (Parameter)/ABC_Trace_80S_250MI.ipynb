# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 80
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Seed 160  | Iteration 250 complete | Duration: 0.3052s | Scout Triggers: 2 | Best Fitness: 0.842105 | Val Fitness: 0.835549
#
# Tracing - Fold 0 Completed in 2367.9151
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.4703s | Scout Triggers: 2 | Best Fitness: 0.850481 | Val Fitness: 0.852343
#
# Tracing - Fold 1 Completed in 2435.6597
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.3065s | Scout Triggers: 1 | Best Fitness: 0.879422 | Val Fitness: 0.811780
#
# Tracing - Fold 2 Completed in 2488.4687
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.3263s | Scout Triggers: 2 | Best Fitness: 0.903934 | Val Fitness: 0.805085
#
# Tracing - Fold 3 Completed in 2281.6225
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.2962s | Scout Triggers: 1 | Best Fitness: 0.834785 | Val Fitness: 0.784284
#
# Tracing - Fold 4 Completed in 2439.1538
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_80SN_40TL_250MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_80SN_40TL_250MI_MCC.png
