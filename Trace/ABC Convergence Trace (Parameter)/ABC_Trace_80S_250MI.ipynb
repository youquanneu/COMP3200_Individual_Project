# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 80
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 250 complete | Duration: 0.7936s | Scout Triggers: 4 | Best Fitness: 0.850732 | Val Fitness: 0.829226
#
# Tracing - Fold 0 Completed in 6210.0135
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.6786s | Scout Triggers: 4 | Best Fitness: 0.857588 | Val Fitness: 0.8469175
#
# Tracing - Fold 1 Completed in 5604.9892
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.5981s | Scout Triggers: 3 | Best Fitness: 0.865210 | Val Fitness: 0.8523433
#
# Tracing - Fold 2 Completed in 4793.8834
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.4430s | Scout Triggers: 3 | Best Fitness: 0.895779 | Val Fitness: 0.7857275
#
# Tracing - Fold 3 Completed in 4131.7947
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.5581s | Scout Triggers: 2 | Best Fitness: 0.838187 | Val Fitness: 0.7846154
#
# Tracing - Fold 4 Completed in 4050.0928
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_80SN_40TL_250MI_Trace.csv
