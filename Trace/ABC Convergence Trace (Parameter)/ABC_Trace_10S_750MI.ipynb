# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 750
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 750 complete | Duration: 0.0868s | Scout Triggers: 3 | Best Fitness: 0.848163 | Val Fitness: 0.825325
#
# Tracing - Fold 0 Completed in 1849.1807
#
# Tracing - Fold 1
# Seed 160  | Iteration 750 complete | Duration: 0.0890s | Scout Triggers: 5 | Best Fitness: 0.823069 | Val Fitness: 0.767220
#
# Tracing - Fold 1 Completed in 1849.1593
#
# Tracing - Fold 2
# Seed 160  | Iteration 750 complete | Duration: 0.1018s | Scout Triggers: 8 | Best Fitness: 0.858936 | Val Fitness: 0.852343
#
# Tracing - Fold 2 Completed in 1885.9095
#
# Tracing - Fold 3
# Seed 160  | Iteration 750 complete | Duration: 0.0899s | Scout Triggers: 3 | Best Fitness: 0.890258 | Val Fitness: 0.725385
#
# Tracing - Fold 3 Completed in 1898.1443
#
# Tracing - Fold 4
# Seed 160  | Iteration 750 complete | Duration: 0.0929s | Scout Triggers: 4 | Best Fitness: 0.824646 | Val Fitness: 0.789057
#
# Tracing - Fold 4 Completed in 1889.4974
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_10SN_5TL_750MI_Trace.csv
