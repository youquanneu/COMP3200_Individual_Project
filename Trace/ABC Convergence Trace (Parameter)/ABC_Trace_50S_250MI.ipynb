# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 50
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 250 complete | Duration: 0.4966s | Scout Triggers: 6 | Best Fitness: 0.828220 | Val Fitness: 0.843077
#
# Tracing - Fold 0 Completed in 4097.3941
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.5165s | Scout Triggers: 2 | Best Fitness: 0.846273 | Val Fitness: 0.8523437
#
# Tracing - Fold 1 Completed in 3706.7410
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.4555s | Scout Triggers: 7 | Best Fitness: 0.858047 | Val Fitness: 0.8044856
#
# Tracing - Fold 2 Completed in 3554.0031
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.4067s | Scout Triggers: 2 | Best Fitness: 0.883213 | Val Fitness: 0.7842845
#
# Tracing - Fold 3 Completed in 3059.2118
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.3839s | Scout Triggers: 6 | Best Fitness: 0.856491 | Val Fitness: 0.7650722
#
# Tracing - Fold 4 Completed in 3029.0791
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_50SN_25TL_250MI_Trace.csv
