# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 50
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 250 complete | Duration: 0.2241s | Scout Triggers: 1 | Best Fitness: 0.837319 | Val Fitness: 0.784615
#
# Tracing - Fold 0 Completed in 1620.9301
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.2199s | Scout Triggers: 2 | Best Fitness: 0.850635 | Val Fitness: 0.869394
#
# Tracing - Fold 1 Completed in 1647.5932
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.2087s | Scout Triggers: 0 | Best Fitness: 0.868159 | Val Fitness: 0.818953
#
# Tracing - Fold 2 Completed in 1628.0553
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.1943s | Scout Triggers: 2 | Best Fitness: 0.887563 | Val Fitness: 0.803846
#
# Tracing - Fold 3 Completed in 1602.6745
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.2055s | Scout Triggers: 3 | Best Fitness: 0.830282 | Val Fitness: 0.771216
#
# Tracing - Fold 4 Completed in 1493.3779
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_50SN_25TL_250MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_50SN_25TL_250MI_MCC.png
