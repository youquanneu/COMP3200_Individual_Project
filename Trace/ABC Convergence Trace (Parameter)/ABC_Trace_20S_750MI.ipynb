# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 750
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 750 complete | Duration: 0.1420s | Scout Triggers: 2 | Best Fitness: 0.841082 | Val Fitness: 0.823575
#
# Tracing - Fold 0 Completed in 3512.4991
#
# Tracing - Fold 1
# Seed 160  | Iteration 750 complete | Duration: 0.1592s | Scout Triggers: 6 | Best Fitness: 0.868288 | Val Fitness: 0.7945113
#
# Tracing - Fold 1 Completed in 3571.3174
#
# Tracing - Fold 2
# Seed 160  | Iteration 750 complete | Duration: 0.1018s | Scout Triggers: 4 | Best Fitness: 0.864500 | Val Fitness: 0.8469179
#
# Tracing - Fold 2 Completed in 3465.5095
#
# Tracing - Fold 3
# Seed 160  | Iteration 750 complete | Duration: 0.0932s | Scout Triggers: 2 | Best Fitness: 0.903241 | Val Fitness: 0.8630776
#
# Tracing - Fold 3 Completed in 2359.3438
#
# Tracing - Fold 4
# Seed 160  | Iteration 750 complete | Duration: 0.1238s | Scout Triggers: 4 | Best Fitness: 0.823632 | Val Fitness: 0.846917
#
# Tracing - Fold 4 Completed in 2692.4924
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_20SN_10TL_750MI_Trace.csv
