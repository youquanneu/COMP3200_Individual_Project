# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 50
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.2713s | Scout Triggers: 4 | Best Fitness: 0.830053 | Val Fitness: 0.825325
#
# Tracing - Fold 0 Completed in 837.9445
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.2608s | Scout Triggers: 3 | Best Fitness: 0.841907 | Val Fitness: 0.843899
#
# Tracing - Fold 1 Completed in 814.8222
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.2338s | Scout Triggers: 2 | Best Fitness: 0.845567 | Val Fitness: 0.843899
#
# Tracing - Fold 2 Completed in 758.6201
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.2378s | Scout Triggers: 5 | Best Fitness: 0.878212 | Val Fitness: 0.823846
#
# Tracing - Fold 3 Completed in 705.1050
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.2233s | Scout Triggers: 5 | Best Fitness: 0.817323 | Val Fitness: 0.8469178
#
# Tracing - Fold 4 Completed in 706.6593
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_ABC_Convergence_Trace_50SN_25TL_100MI_Trace.csv
