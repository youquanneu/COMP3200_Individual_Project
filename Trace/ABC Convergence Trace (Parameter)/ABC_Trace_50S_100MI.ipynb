# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 50
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.1985s | Scout Triggers: 2 | Best Fitness: 0.840187 | Val Fitness: 0.829226
#
# Tracing - Fold 0 Completed in 567.5797
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.1828s | Scout Triggers: 0 | Best Fitness: 0.846506 | Val Fitness: 0.825325
#
# Tracing - Fold 1 Completed in 565.7693
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.1824s | Scout Triggers: 2 | Best Fitness: 0.867979 | Val Fitness: 0.807069
#
# Tracing - Fold 2 Completed in 564.5029
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.1843s | Scout Triggers: 3 | Best Fitness: 0.883087 | Val Fitness: 0.844376
#
# Tracing - Fold 3 Completed in 562.9454
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.1815s | Scout Triggers: 2 | Best Fitness: 0.823002 | Val Fitness: 0.863077
#
# Tracing - Fold 4 Completed in 564.4938
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_50SN_25TL_100MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_50SN_25TL_100MI_MCC.png
