# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 50
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
expr_name = f"ABC_Convergence_Trace_{solution_size}SN_{trial_limit}TL_{max_iteration}MI"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.9141s | Scout Triggers: 1 | Best Fitness: 0.839015 | Val Fitness: 0.846917
#
# Tracing - Fold 0 Completed in 3136.3849
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.9815s | Scout Triggers: 1 | Best Fitness: 0.835408 | Val Fitness: 0.864923
#
# Tracing - Fold 1 Completed in 2943.6261
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.7871s | Scout Triggers: 2 | Best Fitness: 0.858979 | Val Fitness: 0.727372
#
# Tracing - Fold 2 Completed in 2534.6748
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.7401s | Scout Triggers: 2 | Best Fitness: 0.885277 | Val Fitness: 0.765794
#
# Tracing - Fold 3 Completed in 2078.3780
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.5978s | Scout Triggers: 0 | Best Fitness: 0.812510 | Val Fitness: 0.843077
#
# Tracing - Fold 4 Completed in 2026.0755
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_50SN_25TL_100MI_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = True)
# Out:
# [I/O Trace] Figure exported successfully: ../../Storage/Figure\Tuning Tracing/_ABC_Convergence_Trace_50SN_25TL_100MI_MCC.png
