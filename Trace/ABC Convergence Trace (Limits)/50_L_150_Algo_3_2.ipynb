# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 50
max_iteration = 150
trial_limit_init   = round(solution_size * 0.5)
employed_algo3 = True
onlooker_algo3 = False

# %%
for i in range(1,5):
    trial_limit = trial_limit_init * i
    expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")
    ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_3_2_50SN_25TL_150MI_Trace.csv
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_3_2_50SN_50TL_150MI_Trace.csv
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_3_2_50SN_75TL_150MI_Trace.csv
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_3_2_50SN_100TL_150MI_Trace.csv
