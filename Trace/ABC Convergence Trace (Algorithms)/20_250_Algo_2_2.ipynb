# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
employed_algo3 = False
onlooker_algo3 = False

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 250 complete | Duration: 0.0869s | Scout Triggers: 3 | Best Fitness: 0.839998 | Val Fitness: 0.789057
#
# Tracing - Fold 0 Completed in 668.3333
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.0862s | Scout Triggers: 4 | Best Fitness: 0.832610 | Val Fitness: 0.860555
#
# Tracing - Fold 1 Completed in 671.9795
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.0952s | Scout Triggers: 6 | Best Fitness: 0.843630 | Val Fitness: 0.8438997
#
# Tracing - Fold 2 Completed in 661.0134
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.0853s | Scout Triggers: 2 | Best Fitness: 0.882357 | Val Fitness: 0.746129
#
# Tracing - Fold 3 Completed in 660.5632
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.0913s | Scout Triggers: 2 | Best Fitness: 0.811012 | Val Fitness: 0.789057
#
# Tracing - Fold 4 Completed in 661.4104
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_2_2_20SN_10TL_250MI_Trace.csv
