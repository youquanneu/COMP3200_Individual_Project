# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
employed_algo3 = False
onlooker_algo3 = True

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 250 complete | Duration: 0.0453s | Scout Triggers: 2 | Best Fitness: 0.847026 | Val Fitness: 0.789057
#
# Tracing - Fold 0 Completed in 657.2362
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.0508s | Scout Triggers: 5 | Best Fitness: 0.839407 | Val Fitness: 0.829226
#
# Tracing - Fold 1 Completed in 646.4753
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.0464s | Scout Triggers: 3 | Best Fitness: 0.844040 | Val Fitness: 0.794511
#
# Tracing - Fold 2 Completed in 643.0827
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.0489s | Scout Triggers: 4 | Best Fitness: 0.891462 | Val Fitness: 0.765072
#
# Tracing - Fold 3 Completed in 644.5242
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.0387s | Scout Triggers: 0 | Best Fitness: 0.824444 | Val Fitness: 0.846917
#
# Tracing - Fold 4 Completed in 639.3976
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_2_3_20SN_10TL_250MI_Trace.csv
