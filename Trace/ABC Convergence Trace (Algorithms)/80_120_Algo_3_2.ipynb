# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 80
max_iteration = 120
trial_limit   = round(solution_size * 0.5)
employed_algo3 = True
onlooker_algo3 = False

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 120 complete | Duration: 0.1730s | Scout Triggers: 3 | Best Fitness: 0.844690 | Val Fitness: 0.764615
#
# Tracing - Fold 0 Completed in 1199.5506
#
# Tracing - Fold 1
# Seed 160  | Iteration 120 complete | Duration: 0.1880s | Scout Triggers: 0 | Best Fitness: 0.842011 | Val Fitness: 0.748888
#
# Tracing - Fold 1 Completed in 1198.5748
#
# Tracing - Fold 2
# Seed 160  | Iteration 120 complete | Duration: 0.1625s | Scout Triggers: 0 | Best Fitness: 0.853781 | Val Fitness: 0.765072
#
# Tracing - Fold 2 Completed in 1185.8103
#
# Tracing - Fold 3
# Seed 160  | Iteration 120 complete | Duration: 0.1645s | Scout Triggers: 1 | Best Fitness: 0.885055 | Val Fitness: 0.803846
#
# Tracing - Fold 3 Completed in 1213.4892
#
# Tracing - Fold 4
# Seed 160  | Iteration 120 complete | Duration: 0.1486s | Scout Triggers: 1 | Best Fitness: 0.819224 | Val Fitness: 0.804485
#
# Tracing - Fold 4 Completed in 1177.4464
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_3_2_80SN_40TL_120MI_Trace.csv
