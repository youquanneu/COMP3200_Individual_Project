# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 100
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
employed_algo3 = False
onlooker_algo3 = True

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.2096s | Scout Triggers: 1 | Best Fitness: 0.840709 | Val Fitness: 0.804485
#
# Tracing - Fold 0 Completed in 1238.6023
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.2194s | Scout Triggers: 0 | Best Fitness: 0.834471 | Val Fitness: 0.869394
#
# Tracing - Fold 1 Completed in 1247.4133
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.2051s | Scout Triggers: 0 | Best Fitness: 0.864816 | Val Fitness: 0.852343
#
# Tracing - Fold 2 Completed in 1236.6073
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.2091s | Scout Triggers: 1 | Best Fitness: 0.883295 | Val Fitness: 0.784284
#
# Tracing - Fold 3 Completed in 1235.5058
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.1986s | Scout Triggers: 2 | Best Fitness: 0.827947 | Val Fitness: 0.784284
#
# Tracing - Fold 4 Completed in 1261.6887
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_2_3_100SN_50TL_100MI_Trace.csv
