# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
expr_name = f"ABC_Convergence_Trace_Algo_3_2"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = GlobalSetting.solution_size,
                                                   trial_limit      = GlobalSetting.trial_limit,
                                                   max_iteration    = GlobalSetting.max_iteration,
                                                   employed_bee_algo3=True,
                                                   onlooker_bee_algo3=False)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 1.0037s | Scout Triggers: 2 | Best Fitness: 0.854020 | Val Fitness: 0.789057
#
# Tracing - Fold 0 Completed in 4612.9764
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.9794s | Scout Triggers: 2 | Best Fitness: 0.854161 | Val Fitness: 0.785727
#
# Tracing - Fold 1 Completed in 4574.7573
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 1.0048s | Scout Triggers: 2 | Best Fitness: 0.864372 | Val Fitness: 0.794511
#
# Tracing - Fold 2 Completed in 4602.0097
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.9871s | Scout Triggers: 1 | Best Fitness: 0.895141 | Val Fitness: 0.823846
#
# Tracing - Fold 3 Completed in 4588.2760
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.8749s | Scout Triggers: 0 | Best Fitness: 0.835945 | Val Fitness: 0.823575
#
# Tracing - Fold 4 Completed in 4592.5225
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_Algo_3_2_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = False)
