# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 80
max_iteration = 120
trial_limit   = round(solution_size * 0.5)
employed_algo3 = False
onlooker_algo3 = True

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 120 complete | Duration: 0.1710s | Scout Triggers: 1 | Best Fitness: 0.836672 | Val Fitness: 0.846917
#
# Tracing - Fold 0 Completed in 1192.5638
#
# Tracing - Fold 1
# Seed 160  | Iteration 120 complete | Duration: 0.1671s | Scout Triggers: 2 | Best Fitness: 0.841847 | Val Fitness: 0.876588
#
# Tracing - Fold 1 Completed in 1196.6921
#
# Tracing - Fold 2
# Seed 160  | Iteration 120 complete | Duration: 0.1724s | Scout Triggers: 0 | Best Fitness: 0.863667 | Val Fitness: 0.807069
#
# Tracing - Fold 2 Completed in 1185.0460
#
# Tracing - Fold 3
# Seed 160  | Iteration 120 complete | Duration: 0.1613s | Scout Triggers: 1 | Best Fitness: 0.882431 | Val Fitness: 0.823575
#
# Tracing - Fold 3 Completed in 1212.3757
#
# Tracing - Fold 4
# Seed 160  | Iteration 120 complete | Duration: 0.1673s | Scout Triggers: 0 | Best Fitness: 0.837869 | Val Fitness: 0.789057
#
# Tracing - Fold 4 Completed in 1180.2181
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_2_3_80SN_40TL_120MI_Trace.csv
