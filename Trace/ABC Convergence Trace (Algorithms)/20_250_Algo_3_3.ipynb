# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 20
max_iteration = 250
trial_limit   = round(solution_size * 0.5)
employed_algo3 = True
onlooker_algo3 = True

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 250 complete | Duration: 0.0067s | Scout Triggers: 2 | Best Fitness: 0.826253 | Val Fitness: 0.789057
#
# Tracing - Fold 0 Completed in 651.4426
#
# Tracing - Fold 1
# Seed 160  | Iteration 250 complete | Duration: 0.0085s | Scout Triggers: 3 | Best Fitness: 0.842042 | Val Fitness: 0.852343
#
# Tracing - Fold 1 Completed in 641.1971
#
# Tracing - Fold 2
# Seed 160  | Iteration 250 complete | Duration: 0.0047s | Scout Triggers: 1 | Best Fitness: 0.864385 | Val Fitness: 0.811780
#
# Tracing - Fold 2 Completed in 638.1730
#
# Tracing - Fold 3
# Seed 160  | Iteration 250 complete | Duration: 0.0066s | Scout Triggers: 2 | Best Fitness: 0.878967 | Val Fitness: 0.843899
#
# Tracing - Fold 3 Completed in 638.9351
#
# Tracing - Fold 4
# Seed 160  | Iteration 250 complete | Duration: 0.0059s | Scout Triggers: 2 | Best Fitness: 0.808561 | Val Fitness: 0.843077
#
# Tracing - Fold 4 Completed in 632.1646
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_3_3_20SN_10TL_250MI_Trace.csv
