# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 50
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
employed_algo3 = True
onlooker_algo3 = True

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.0074s | Scout Triggers: 1 | Best Fitness: 0.826681 | Val Fitness: 0.807069
#
# Tracing - Fold 0 Completed in 943.4701
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.0075s | Scout Triggers: 1 | Best Fitness: 0.839182 | Val Fitness: 0.807069
#
# Tracing - Fold 1 Completed in 930.8491
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.0082s | Scout Triggers: 1 | Best Fitness: 0.866640 | Val Fitness: 0.811780
#
# Tracing - Fold 2 Completed in 928.6463
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.0055s | Scout Triggers: 0 | Best Fitness: 0.883992 | Val Fitness: 0.803846
#
# Tracing - Fold 3 Completed in 933.1304
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.0056s | Scout Triggers: 0 | Best Fitness: 0.813782 | Val Fitness: 0.823575
#
# Tracing - Fold 4 Completed in 930.8201
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_3_3_50SN_25TL_150MI_Trace.csv
