# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
expr_name = f"ABC_Convergence_Trace_Algo_2_2"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = GlobalSetting.solution_size,
                                                   trial_limit      = GlobalSetting.trial_limit,
                                                   max_iteration    = GlobalSetting.max_iteration,
                                                   employed_bee_algo3=False,
                                                   onlooker_bee_algo3=False)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 1.0035s | Scout Triggers: 2 | Best Fitness: 0.854532 | Val Fitness: 0.886766
#
# Tracing - Fold 0 Completed in 4648.9822
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.9790s | Scout Triggers: 1 | Best Fitness: 0.864830 | Val Fitness: 0.789057
#
# Tracing - Fold 1 Completed in 4606.4734
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 1.0116s | Scout Triggers: 3 | Best Fitness: 0.879477 | Val Fitness: 0.789057
#
# Tracing - Fold 2 Completed in 4639.4230
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 1.0025s | Scout Triggers: 3 | Best Fitness: 0.885484 | Val Fitness: 0.744993
#
# Tracing - Fold 3 Completed in 4616.4001
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.4988s | Scout Triggers: 3 | Best Fitness: 0.846717 | Val Fitness: 0.862866
#
# Tracing - Fold 4 Completed in 4542.9178
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_Algo_2_2_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = False)
