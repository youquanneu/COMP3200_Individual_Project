# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 1000
trial_limit   = round(solution_size * 0.5)
employed_algo3 = False
onlooker_algo3 = False

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 1000 complete | Duration: 0.0537s | Scout Triggers: 6 | Best Fitness: 0.850828 | Val Fitness: 0.825325
#
# Tracing - Fold 0 Completed in 1421.3993
#
# Tracing - Fold 1
# Seed 160  | Iteration 1000 complete | Duration: 0.0537s | Scout Triggers: 6 | Best Fitness: 0.852870 | Val Fitness: 0.777350
#
# Tracing - Fold 1 Completed in 1433.9535
#
# Tracing - Fold 2
# Seed 160  | Iteration 1000 complete | Duration: 0.0576s | Scout Triggers: 4 | Best Fitness: 0.855646 | Val Fitness: 0.835549
#
# Tracing - Fold 2 Completed in 1447.7735
#
# Tracing - Fold 3
# Seed 160  | Iteration 1000 complete | Duration: 0.0482s | Scout Triggers: 1 | Best Fitness: 0.872019 | Val Fitness: 0.863077
#
# Tracing - Fold 3 Completed in 1447.5044
#
# Tracing - Fold 4
# Seed 160  | Iteration 1000 complete | Duration: 0.0437s | Scout Triggers: 4 | Best Fitness: 0.824678 | Val Fitness: 0.846917
#
# Tracing - Fold 4 Completed in 1441.9051
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_2_2_10SN_5TL_1000MI_Trace.csv
