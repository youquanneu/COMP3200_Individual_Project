# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 100
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
employed_algo3 = False
onlooker_algo3 = False

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.4085s | Scout Triggers: 4 | Best Fitness: 0.828689 | Val Fitness: 0.8469173
#
# Tracing - Fold 0 Completed in 1248.6160
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.4404s | Scout Triggers: 7 | Best Fitness: 0.844210 | Val Fitness: 0.8469174
#
# Tracing - Fold 1 Completed in 1262.5947
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.4174s | Scout Triggers: 5 | Best Fitness: 0.859661 | Val Fitness: 0.8253256
#
# Tracing - Fold 2 Completed in 1247.8323
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.4071s | Scout Triggers: 2 | Best Fitness: 0.886219 | Val Fitness: 0.823846
#
# Tracing - Fold 3 Completed in 1247.3714
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.3744s | Scout Triggers: 7 | Best Fitness: 0.827412 | Val Fitness: 0.8438992
#
# Tracing - Fold 4 Completed in 1267.4421
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_2_2_100SN_50TL_100MI_Trace.csv
