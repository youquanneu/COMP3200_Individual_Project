# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 100
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
employed_algo3 = True
onlooker_algo3 = True

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.0133s | Scout Triggers: 1 | Best Fitness: 0.839107 | Val Fitness: 0.789057
#
# Tracing - Fold 0 Completed in 1226.9199
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.0122s | Scout Triggers: 0 | Best Fitness: 0.856189 | Val Fitness: 0.876588
#
# Tracing - Fold 1 Completed in 1233.4072
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.0105s | Scout Triggers: 0 | Best Fitness: 0.876690 | Val Fitness: 0.829226
#
# Tracing - Fold 2 Completed in 1220.4652
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.0102s | Scout Triggers: 0 | Best Fitness: 0.890948 | Val Fitness: 0.826124
#
# Tracing - Fold 3 Completed in 1219.3516
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.0138s | Scout Triggers: 1 | Best Fitness: 0.826578 | Val Fitness: 0.902158
#
# Tracing - Fold 4 Completed in 1248.3403
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_3_3_100SN_50TL_100MI_Trace.csv
