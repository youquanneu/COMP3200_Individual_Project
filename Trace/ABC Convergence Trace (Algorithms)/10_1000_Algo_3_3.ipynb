# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 1000
trial_limit   = round(solution_size * 0.5)
employed_algo3 = True
onlooker_algo3 = True

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 1000 complete | Duration: 0.0075s | Scout Triggers: 3 | Best Fitness: 0.854532 | Val Fitness: 0.829226
#
# Tracing - Fold 0 Completed in 1391.1026
#
# Tracing - Fold 1
# Seed 160  | Iteration 1000 complete | Duration: 0.0065s | Scout Triggers: 2 | Best Fitness: 0.850253 | Val Fitness: 0.860555
#
# Tracing - Fold 1 Completed in 1401.2544
#
# Tracing - Fold 2
# Seed 160  | Iteration 1000 complete | Duration: 0.0080s | Scout Triggers: 3 | Best Fitness: 0.863710 | Val Fitness: 0.829226
#
# Tracing - Fold 2 Completed in 1412.5430
#
# Tracing - Fold 3
# Seed 160  | Iteration 1000 complete | Duration: 0.0097s | Scout Triggers: 4 | Best Fitness: 0.901593 | Val Fitness: 0.804485
#
# Tracing - Fold 3 Completed in 1418.4473
#
# Tracing - Fold 4
# Seed 160  | Iteration 1000 complete | Duration: 0.0051s | Scout Triggers: 2 | Best Fitness: 0.822982 | Val Fitness: 0.746129
#
# Tracing - Fold 4 Completed in 1434.2338
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_3_3_10SN_5TL_1000MI_Trace.csv
