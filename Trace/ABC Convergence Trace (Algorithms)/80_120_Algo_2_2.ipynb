# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 80
max_iteration = 120
trial_limit   = round(solution_size * 0.5)
employed_algo3 = False
onlooker_algo3 = False

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 120 complete | Duration: 0.3464s | Scout Triggers: 1 | Best Fitness: 0.835228 | Val Fitness: 0.883312
#
# Tracing - Fold 0 Completed in 1214.6575
#
# Tracing - Fold 1
# Seed 160  | Iteration 120 complete | Duration: 0.3209s | Scout Triggers: 2 | Best Fitness: 0.840236 | Val Fitness: 0.8523433
#
# Tracing - Fold 1 Completed in 1218.9924
#
# Tracing - Fold 2
# Seed 160  | Iteration 120 complete | Duration: 0.3323s | Scout Triggers: 6 | Best Fitness: 0.857387 | Val Fitness: 0.8523439
#
# Tracing - Fold 2 Completed in 1204.4291
#
# Tracing - Fold 3
# Seed 160  | Iteration 120 complete | Duration: 0.3272s | Scout Triggers: 1 | Best Fitness: 0.888801 | Val Fitness: 0.7449931
#
# Tracing - Fold 3 Completed in 1233.3628
#
# Tracing - Fold 4
# Seed 160  | Iteration 120 complete | Duration: 0.3017s | Scout Triggers: 8 | Best Fitness: 0.833776 | Val Fitness: 0.744993
#
# Tracing - Fold 4 Completed in 1187.8283
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_2_2_80SN_40TL_120MI_Trace.csv
