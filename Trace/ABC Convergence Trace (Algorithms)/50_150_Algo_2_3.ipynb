# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 50
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
employed_algo3 = False
onlooker_algo3 = True

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.1048s | Scout Triggers: 2 | Best Fitness: 0.837596 | Val Fitness: 0.883312
#
# Tracing - Fold 0 Completed in 947.5619
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.1009s | Scout Triggers: 0 | Best Fitness: 0.844284 | Val Fitness: 0.852343
#
# Tracing - Fold 1 Completed in 931.5706
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.1029s | Scout Triggers: 1 | Best Fitness: 0.874867 | Val Fitness: 0.748888
#
# Tracing - Fold 2 Completed in 928.8005
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.1072s | Scout Triggers: 2 | Best Fitness: 0.884981 | Val Fitness: 0.745385
#
# Tracing - Fold 3 Completed in 935.5210
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.1045s | Scout Triggers: 0 | Best Fitness: 0.821951 | Val Fitness: 0.789057
#
# Tracing - Fold 4 Completed in 931.0189
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_2_3_50SN_25TL_150MI_Trace.csv
