# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 1000
trial_limit   = round(solution_size * 0.5)
employed_algo3 = True
onlooker_algo3 = False

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 1000 complete | Duration: 0.0290s | Scout Triggers: 3 | Best Fitness: 0.850732 | Val Fitness: 0.846917
#
# Tracing - Fold 0 Completed in 1383.8968
#
# Tracing - Fold 1
# Seed 160  | Iteration 1000 complete | Duration: 0.0225s | Scout Triggers: 0 | Best Fitness: 0.854621 | Val Fitness: 0.789057
#
# Tracing - Fold 1 Completed in 1393.0069
#
# Tracing - Fold 2
# Seed 160  | Iteration 1000 complete | Duration: 0.0237s | Scout Triggers: 1 | Best Fitness: 0.853013 | Val Fitness: 0.811780
#
# Tracing - Fold 2 Completed in 1405.5299
#
# Tracing - Fold 3
# Seed 160  | Iteration 1000 complete | Duration: 0.0242s | Scout Triggers: 1 | Best Fitness: 0.886992 | Val Fitness: 0.823846
#
# Tracing - Fold 3 Completed in 1410.7653
#
# Tracing - Fold 4
# Seed 160  | Iteration 1000 complete | Duration: 0.0236s | Scout Triggers: 2 | Best Fitness: 0.856592 | Val Fitness: 0.823575
#
# Tracing - Fold 4 Completed in 1426.7381
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_3_2_10SN_5TL_1000MI_Trace.csv
