# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
expr_name = f"ABC_Convergence_Trace_Algo_2_3"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = GlobalSetting.solution_size,
                                                   trial_limit      = GlobalSetting.trial_limit,
                                                   max_iteration    = GlobalSetting.max_iteration,
                                                   employed_bee_algo3=False,
                                                   onlooker_bee_algo3=True)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.9896s | Scout Triggers: 0 | Best Fitness: 0.853602 | Val Fitness: 0.829226
#
# Tracing - Fold 0 Completed in 4612.4951
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 1.0582s | Scout Triggers: 0 | Best Fitness: 0.862201 | Val Fitness: 0.823575
#
# Tracing - Fold 1 Completed in 4572.7785
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 1.0157s | Scout Triggers: 1 | Best Fitness: 0.881469 | Val Fitness: 0.892906
#
# Tracing - Fold 2 Completed in 4597.9329
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.9985s | Scout Triggers: 1 | Best Fitness: 0.894714 | Val Fitness: 0.744993
#
# Tracing - Fold 3 Completed in 4574.7324
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 1.1715s | Scout Triggers: 3 | Best Fitness: 0.828128 | Val Fitness: 0.727372
#
# Tracing - Fold 4 Completed in 4584.9444
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_Algo_2_3_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = False)
