# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 100
max_iteration = 100
trial_limit   = round(solution_size * 0.5)
employed_algo3 = True
onlooker_algo3 = False

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 100 complete | Duration: 0.2515s | Scout Triggers: 1 | Best Fitness: 0.843685 | Val Fitness: 0.825325
#
# Tracing - Fold 0 Completed in 1236.5494
#
# Tracing - Fold 1
# Seed 160  | Iteration 100 complete | Duration: 0.2058s | Scout Triggers: 0 | Best Fitness: 0.838702 | Val Fitness: 0.829226
#
# Tracing - Fold 1 Completed in 1242.1259
#
# Tracing - Fold 2
# Seed 160  | Iteration 100 complete | Duration: 0.2080s | Scout Triggers: 1 | Best Fitness: 0.856543 | Val Fitness: 0.846917
#
# Tracing - Fold 2 Completed in 1231.4451
#
# Tracing - Fold 3
# Seed 160  | Iteration 100 complete | Duration: 0.2078s | Scout Triggers: 1 | Best Fitness: 0.884782 | Val Fitness: 0.843899
#
# Tracing - Fold 3 Completed in 1230.3556
#
# Tracing - Fold 4
# Seed 160  | Iteration 100 complete | Duration: 0.1885s | Scout Triggers: 1 | Best Fitness: 0.821754 | Val Fitness: 0.823575
#
# Tracing - Fold 4 Completed in 1256.2879
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_3_2_100SN_50TL_100MI_Trace.csv
