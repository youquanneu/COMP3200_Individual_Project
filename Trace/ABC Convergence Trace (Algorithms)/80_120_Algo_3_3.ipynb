# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 80
max_iteration = 120
trial_limit   = round(solution_size * 0.5)
employed_algo3 = True
onlooker_algo3 = True

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 120 complete | Duration: 0.0144s | Scout Triggers: 3 | Best Fitness: 0.842117 | Val Fitness: 0.825325
#
# Tracing - Fold 0 Completed in 1187.6806
#
# Tracing - Fold 1
# Seed 160  | Iteration 120 complete | Duration: 0.0104s | Scout Triggers: 1 | Best Fitness: 0.853132 | Val Fitness: 0.825325
#
# Tracing - Fold 1 Completed in 1191.9319
#
# Tracing - Fold 2
# Seed 160  | Iteration 120 complete | Duration: 0.0084s | Scout Triggers: 0 | Best Fitness: 0.863648 | Val Fitness: 0.804485
#
# Tracing - Fold 2 Completed in 1178.3535
#
# Tracing - Fold 3
# Seed 160  | Iteration 120 complete | Duration: 0.0112s | Scout Triggers: 1 | Best Fitness: 0.905591 | Val Fitness: 0.768645
#
# Tracing - Fold 3 Completed in 1214.8510
#
# Tracing - Fold 4
# Seed 160  | Iteration 120 complete | Duration: 0.0085s | Scout Triggers: 0 | Best Fitness: 0.831890 | Val Fitness: 0.803846
#
# Tracing - Fold 4 Completed in 1182.6437
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_3_3_80SN_40TL_120MI_Trace.csv
