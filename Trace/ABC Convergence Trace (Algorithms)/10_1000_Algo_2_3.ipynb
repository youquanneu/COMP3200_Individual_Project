# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 10
max_iteration = 1000
trial_limit   = round(solution_size * 0.5)
employed_algo3 = False
onlooker_algo3 = True

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 1000 complete | Duration: 0.0253s | Scout Triggers: 2 | Best Fitness: 0.857542 | Val Fitness: 0.846917
#
# Tracing - Fold 0 Completed in 1383.5756
#
# Tracing - Fold 1
# Seed 160  | Iteration 1000 complete | Duration: 0.0295s | Scout Triggers: 4 | Best Fitness: 0.823066 | Val Fitness: 0.846917
#
# Tracing - Fold 1 Completed in 1394.4403
#
# Tracing - Fold 2
# Seed 160  | Iteration 1000 complete | Duration: 0.0221s | Scout Triggers: 0 | Best Fitness: 0.868293 | Val Fitness: 0.825325
#
# Tracing - Fold 2 Completed in 1408.4056
#
# Tracing - Fold 3
# Seed 160  | Iteration 1000 complete | Duration: 0.0259s | Scout Triggers: 1 | Best Fitness: 0.905191 | Val Fitness: 0.803846
#
# Tracing - Fold 3 Completed in 1412.2016
#
# Tracing - Fold 4
# Seed 160  | Iteration 1000 complete | Duration: 0.0374s | Scout Triggers: 3 | Best Fitness: 0.834511 | Val Fitness: 0.843077
#
# Tracing - Fold 4 Completed in 1431.8744
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_2_3_10SN_5TL_1000MI_Trace.csv
