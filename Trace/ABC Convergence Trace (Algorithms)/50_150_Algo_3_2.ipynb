# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Methodology import ABC_Testing

# %%
solution_size = 50
max_iteration = 150
trial_limit   = round(solution_size * 0.5)
employed_algo3 = True
onlooker_algo3 = False

expr_name = (f"Algo_{3 if employed_algo3 else 2}_{3 if onlooker_algo3 else 2}"
             f"_{solution_size}SN_{trial_limit}TL_{max_iteration}MI")

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = solution_size,
                                                   trial_limit      = trial_limit,
                                                   max_iteration    = max_iteration,
                                                   employed_bee_algo3 = employed_algo3,
                                                   onlooker_bee_algo3 = onlooker_algo3)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 0.1030s | Scout Triggers: 1 | Best Fitness: 0.840603 | Val Fitness: 0.811780
#
# Tracing - Fold 0 Completed in 950.6848
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.1037s | Scout Triggers: 1 | Best Fitness: 0.842875 | Val Fitness: 0.843899
#
# Tracing - Fold 1 Completed in 937.4668
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.1047s | Scout Triggers: 1 | Best Fitness: 0.852464 | Val Fitness: 0.789057
#
# Tracing - Fold 2 Completed in 935.2871
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.1080s | Scout Triggers: 2 | Best Fitness: 0.894231 | Val Fitness: 0.823575
#
# Tracing - Fold 3 Completed in 941.0339
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.0980s | Scout Triggers: 1 | Best Fitness: 0.839490 | Val Fitness: 0.789057
#
# Tracing - Fold 4 Completed in 933.6225
# [I/O Trace] Record exported successfully: C:\Users\yqn1e23\PycharmProjects\COMP3200_Individual_Project\Storage\Record\Trace History/cleaned_Algo_3_2_50SN_25TL_150MI_Trace.csv
