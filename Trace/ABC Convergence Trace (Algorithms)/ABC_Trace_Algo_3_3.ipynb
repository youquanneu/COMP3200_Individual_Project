# %%
from Pipeline.Algorithm.ArtificialBeeColonyElmCV import ArtificialBeeColonyElmCV
from Pipeline.Global.GlobalSetting import GlobalSetting
from Pipeline.Global.Plotting import Plotting
from Pipeline.Methodology import ABC_Testing

# %%
expr_name = f"ABC_Convergence_Trace_Algo_3_3"

# %%
trace_result = ABC_Testing.evaluate_abc_parameters(ArtificialBeeColonyElmCV,
                                                   expr_name,
                                                   solution_size    = GlobalSetting.solution_size,
                                                   trial_limit      = GlobalSetting.trial_limit,
                                                   max_iteration    = GlobalSetting.max_iteration,
                                                   employed_bee_algo3=True,
                                                   onlooker_bee_algo3=True)
# Out:
# Tracing - Fold 0
# Seed 160  | Iteration 150 complete | Duration: 1.0317s | Scout Triggers: 1 | Best Fitness: 0.850828 | Val Fitness: 0.864923
#
# Tracing - Fold 0 Completed in 4622.5776
#
# Tracing - Fold 1
# Seed 160  | Iteration 150 complete | Duration: 0.9778s | Scout Triggers: 1 | Best Fitness: 0.868288 | Val Fitness: 0.829226
#
# Tracing - Fold 1 Completed in 4579.8234
#
# Tracing - Fold 2
# Seed 160  | Iteration 150 complete | Duration: 0.9806s | Scout Triggers: 0 | Best Fitness: 0.868642 | Val Fitness: 0.852343
#
# Tracing - Fold 2 Completed in 4607.1271
#
# Tracing - Fold 3
# Seed 160  | Iteration 150 complete | Duration: 0.9795s | Scout Triggers: 1 | Best Fitness: 0.896066 | Val Fitness: 0.843899
#
# Tracing - Fold 3 Completed in 4583.9746
#
# Tracing - Fold 4
# Seed 160  | Iteration 150 complete | Duration: 0.8507s | Scout Triggers: 0 | Best Fitness: 0.833286 | Val Fitness: 0.745385
#
# Tracing - Fold 4 Completed in 4588.5615
# [I/O Trace] Record exported successfully: ../../Storage/Record\Trace History/cleaned_ABC_Convergence_Trace_Algo_3_3_Trace.csv

# %%
Plotting.plot_rigorous_convergence(trace_result,
                                   experiment_name  = expr_name,
                                   is_final_record  = False)
